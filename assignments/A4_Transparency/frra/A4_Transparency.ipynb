# %% [markdown]
# Course Human-Centered Data Science ([HCDS](https://www.mi.fu-berlin.de/en/inf/groups/hcc/teaching/winter_term_2020_21/course_human_centered_data_science.html)) - Winter Term 2020/21 - [HCC](https://www.mi.fu-berlin.de/en/inf/groups/hcc/index.html) | [Freie Universität Berlin](https://www.fu-berlin.de/)
#
# ***
# #Transparency

# %% [markdown]
# ## [1] General understanding
# > What is the model about and who is using it?
#
# * What is your model about?
#
#   * The model predicts whether an article will need speedy deletion (because it is, for example, spam, vandalism, attack).
#
#
# * Why is this model useful?
#
#   * The articles can be edited by anyone, therefor it is necessary to prevent actions like spam or vandalism.
#
#
# * Who is using this model?
#
#   * The model is mainly used to help wikipedians to faster find vandalising edits.
#
#
# * What are stakeholder or users of ORES?
#
#   * Everyone who is using and editing wikipedia is basically a stakeholder of the ORES, since malfunctions or biases in the algorithm prevent people from getting the best and most accurate informations possible.
#
# * Why is this model useful to wikipedia?
#
#   * The model is necessary for wikipedia, since the amount of daily edited and added articles is too large to be overviewed by just humans. Compared to it's predicessors it also improves the user friendlyness towards new ediors, which is also in wikipedia's best interest, since this implies that more people can contribute and therefor more knowledge can be obtained.
#
# * What applications/projects/... within wikipedia are using this model?
#
#   * enwiki, testwiki, simplewiki and ptwiki are using this model.

# %% [markdown]
# ## [2] API

# %%
import pandas as pd
import requests
import json
import pprint
import numpy as np

# %% [markdown]
# ### https://ores.wikimedia.org/v3/scores/

# %% [markdown]
# The "scores" API call retrieves information about all projects and which model with the associated version is available for this project.

# %%
call1 = requests.get('https://ores.wikimedia.org/v3/scores/')
scores = call1.json()
c1 = json.dumps(scores, indent = 1)
p1 = json.loads(c1)
pprint.pprint(c1, width= 200)
# Out:
# ('{\n'
#  ' "arwiki": {\n'
#  '  "models": {\n'
#  '   "articletopic": {\n'
#  '    "version": "1.2.0"\n'
#  '   },\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "bnwiki": {\n'
#  '  "models": {\n'
#  '   "reverted": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "bswiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "cawiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "cswiki": {\n'
#  '  "models": {\n'
#  '   "articletopic": {\n'
#  '    "version": "1.2.0"\n'
#  '   },\n'
#  '   "damaging": {\n'
#  '    "version": "0.6.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.6.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "dewiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "elwiki": {\n'
#  '  "models": {\n'
#  '   "reverted": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "enwiki": {\n'
#  '  "models": {\n'
#  '   "articlequality": {\n'
#  '    "version": "0.8.2"\n'
#  '   },\n'
#  '   "articletopic": {\n'
#  '    "version": "1.2.0"\n'
#  '   },\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "draftquality": {\n'
#  '    "version": "0.2.1"\n'
#  '   },\n'
#  '   "drafttopic": {\n'
#  '    "version": "1.2.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "wp10": {\n'
#  '    "version": "0.8.2"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "enwiktionary": {\n'
#  '  "models": {\n'
#  '   "reverted": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "eswiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "eswikibooks": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "eswikiquote": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "etwiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "euwiki": {\n'
#  '  "models": {\n'
#  '   "articlequality": {\n'
#  '    "version": "0.8.1"\n'
#  '   },\n'
#  '   "wp10": {\n'
#  '    "version": "0.8.1"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "fakewiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.0.3"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.0.3"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "fawiki": {\n'
#  '  "models": {\n'
#  '   "articlequality": {\n'
#  '    "version": "0.8.0"\n'
#  '   },\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "wp10": {\n'
#  '    "version": "0.8.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "fiwiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "frwiki": {\n'
#  '  "models": {\n'
#  '   "articlequality": {\n'
#  '    "version": "0.8.0"\n'
#  '   },\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "wp10": {\n'
#  '    "version": "0.8.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "frwikisource": {\n'
#  '  "models": {\n'
#  '   "pagelevel": {\n'
#  '    "version": "0.3.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "glwiki": {\n'
#  '  "models": {\n'
#  '   "articlequality": {\n'
#  '    "version": "0.8.0"\n'
#  '   },\n'
#  '   "reverted": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "hewiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "hrwiki": {\n'
#  '  "models": {\n'
#  '   "reverted": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "huwiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "idwiki": {\n'
#  '  "models": {\n'
#  '   "reverted": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "iswiki": {\n'
#  '  "models": {\n'
#  '   "reverted": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "itwiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "jawiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "kowiki": {\n'
#  '  "models": {\n'
#  '   "articletopic": {\n'
#  '    "version": "1.2.0"\n'
#  '   },\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "lvwiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "nlwiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "nowiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "plwiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "ptwiki": {\n'
#  '  "models": {\n'
#  '   "articlequality": {\n'
#  '    "version": "0.8.0"\n'
#  '   },\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "draftquality": {\n'
#  '    "version": "0.2.1"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "rowiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "ruwiki": {\n'
#  '  "models": {\n'
#  '   "articlequality": {\n'
#  '    "version": "0.8.0"\n'
#  '   },\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "wp10": {\n'
#  '    "version": "0.8.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "simplewiki": {\n'
#  '  "models": {\n'
#  '   "articlequality": {\n'
#  '    "version": "0.8.2"\n'
#  '   },\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "draftquality": {\n'
#  '    "version": "0.2.1"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "wp10": {\n'
#  '    "version": "0.8.2"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "sqwiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "srwiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "svwiki": {\n'
#  '  "models": {\n'
#  '   "articlequality": {\n'
#  '    "version": "0.8.0"\n'
#  '   },\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "tawiki": {\n'
#  '  "models": {\n'
#  '   "reverted": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "testwiki": {\n'
#  '  "models": {\n'
#  '   "articlequality": {\n'
#  '    "version": "0.8.2"\n'
#  '   },\n'
#  '   "articletopic": {\n'
#  '    "version": "1.2.0"\n'
#  '   },\n'
#  '   "damaging": {\n'
#  '    "version": "0.0.3"\n'
#  '   },\n'
#  '   "draftquality": {\n'
#  '    "version": "0.2.1"\n'
#  '   },\n'
#  '   "drafttopic": {\n'
#  '    "version": "1.2.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.0.3"\n'
#  '   },\n'
#  '   "reverted": {\n'
#  '    "version": "0.0.3"\n'
#  '   },\n'
#  '   "wp10": {\n'
#  '    "version": "0.8.2"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "trwiki": {\n'
#  '  "models": {\n'
#  '   "articlequality": {\n'
#  '    "version": "0.8.0"\n'
#  '   },\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "wp10": {\n'
#  '    "version": "0.8.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "ukwiki": {\n'
#  '  "models": {\n'
#  '   "articlequality": {\n'
#  '    "version": "0.8.0"\n'
#  '   },\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "viwiki": {\n'
#  '  "models": {\n'
#  '   "articletopic": {\n'
#  '    "version": "1.2.0"\n'
#  '   },\n'
#  '   "reverted": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "wikidatawiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "itemquality": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' },\n'
#  ' "zhwiki": {\n'
#  '  "models": {\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.0"\n'
#  '   }\n'
#  '  }\n'
#  ' }\n'
#  '}')

# %%
models = {'project': [],'model':[],'version':[]}
model_df = pd.DataFrame(models, columns = ['model','project', 'version' ])

for project in scores.keys():
  for model in scores[project]['models'].keys():
    version = scores[project]['models'][model]['version']
    model_df = model_df.append({'model':model, 'project': project, 'version':version}, ignore_index=True)
model_df[model_df['model'] == 'draftquality']
# Out:
#            model     project version
# 17  draftquality      enwiki   0.2.1
# 71  draftquality      ptwiki   0.2.1
# 81  draftquality  simplewiki   0.2.1
# 95  draftquality    testwiki   0.2.1

# %% [markdown]
# ###https://ores.wikimedia.org/v3/scores/?model_info

# %% [markdown]
# This API call gives detailed information about:
#
# *   environment
# *   params
# *   score schema
# *   statistics
# *   type
# *   version
#
# of all available models in each project.

# %%
call2 = requests.get('https://ores.wikimedia.org/v3/scores/?model_info')
model_info = call2.json()
c2 = json.dumps(model_info, indent= 2)
p2 = json.loads(c2)
pprint.pprint(c2, width= 200, depth= 2)
# Out:
# Streaming output truncated to the last 5000 lines.
#  '              "c": 0.934,\n'
#  '              "km": 0.954,\n'
#  '              "sm": 0.961,\n'
#  '              "taslak": 0.806\n'
#  '            },\n'
#  '            "macro": 0.915,\n'
#  '            "micro": 0.848\n'
#  '          },\n'
#  '          "!precision": {\n'
#  '            "labels": {\n'
#  '              "b": 0.969,\n'
#  '              "baslag\\u0131\\u00e7": 0.866,\n'
#  '              "c": 0.95,\n'
#  '              "km": 0.994,\n'
#  '              "sm": 0.995,\n'
#  '              "taslak": 0.707\n'
#  '            },\n'
#  '            "macro": 0.914,\n'
#  '            "micro": 0.791\n'
#  '          },\n'
#  '          "!recall": {\n'
#  '            "labels": {\n'
#  '              "b": 0.94,\n'
#  '              "baslag\\u0131\\u00e7": 0.89,\n'
#  '              "c": 0.918,\n'
#  '              "km": 0.917,\n'
#  '              "sm": 0.93,\n'
#  '              "taslak": 0.937\n'
#  '            },\n'
#  '            "macro": 0.922,\n'
#  '            "micro": 0.923\n'
#  '          },\n'
#  '          "accuracy": {\n'
#  '            "labels": {\n'
#  '              "b": 0.915,\n'
#  '              "baslag\\u0131\\u00e7": 0.814,\n'
#  '              "c": 0.881,\n'
#  '              "km": 0.913,\n'
#  '              "sm": 0.927,\n'
#  '              "taslak": 0.81\n'
#  '            },\n'
#  '            "macro": 0.877,\n'
#  '            "micro": 0.826\n'
#  '          },\n'
#  '          "counts": {\n'
#  '            "labels": {\n'
#  '              "b": 270,\n'
#  '              "baslag\\u0131\\u00e7": 271,\n'
#  '              "c": 269,\n'
#  '              "km": 267,\n'
#  '              "sm": 270,\n'
#  '              "taslak": 267\n'
#  '            },\n'
#  '            "n": 1614,\n'
#  '            "predictions": {\n'
#  '              "b": {\n'
#  '                "b": 127,\n'
#  '                "baslag\\u0131\\u00e7": 17,\n'
#  '                "c": 38,\n'
#  '                "km": 38,\n'
#  '                "sm": 45,\n'
#  '                "taslak": 5\n'
#  '              },\n'
#  '              "baslag\\u0131\\u00e7": {\n'
#  '                "b": 2,\n'
#  '                "baslag\\u0131\\u00e7": 158,\n'
#  '                "c": 43,\n'
#  '                "km": 4,\n'
#  '                "sm": 0,\n'
#  '                "taslak": 64\n'
#  '              },\n'
#  '              "c": {\n'
#  '                "b": 39,\n'
#  '                "baslag\\u0131\\u00e7": 50,\n'
#  '                "c": 131,\n'
#  '                "km": 29,\n'
#  '                "sm": 7,\n'
#  '                "taslak": 13\n'
#  '              },\n'
#  '              "km": {\n'
#  '                "b": 14,\n'
#  '                "baslag\\u0131\\u00e7": 6,\n'
#  '                "c": 20,\n'
#  '                "km": 184,\n'
#  '                "sm": 42,\n'
#  '                "taslak": 1\n'
#  '              },\n'
#  '              "sm": {\n'
#  '                "b": 26,\n'
#  '                "baslag\\u0131\\u00e7": 3,\n'
#  '                "c": 6,\n'
#  '                "km": 41,\n'
#  '                "sm": 192,\n'
#  '                "taslak": 2\n'
#  '              },\n'
#  '              "taslak": {\n'
#  '                "b": 0,\n'
#  '                "baslag\\u0131\\u00e7": 72,\n'
#  '                "c": 3,\n'
#  '                "km": 0,\n'
#  '                "sm": 0,\n'
#  '                "taslak": 192\n'
#  '              }\n'
#  '            }\n'
#  '          },\n'
#  '          "f1": {\n'
#  '            "labels": {\n'
#  '              "b": 0.37,\n'
#  '              "baslag\\u0131\\u00e7": 0.608,\n'
#  '              "c": 0.413,\n'
#  '              "km": 0.212,\n'
#  '              "sm": 0.234,\n'
#  '              "taslak": 0.815\n'
#  '            },\n'
#  '            "macro": 0.442,\n'
#  '            "micro": 0.686\n'
#  '          },\n'
#  '          "filter_rate": {\n'
#  '            "labels": {\n'
#  '              "b": 0.918,\n'
#  '              "baslag\\u0131\\u00e7": 0.773,\n'
#  '              "c": 0.883,\n'
#  '              "km": 0.907,\n'
#  '              "sm": 0.92,\n'
#  '              "taslak": 0.556\n'
#  '            },\n'
#  '            "macro": 0.826,\n'
#  '            "micro": 0.669\n'
#  '          },\n'
#  '          "fpr": {\n'
#  '            "labels": {\n'
#  '              "b": 0.06,\n'
#  '              "baslag\\u0131\\u00e7": 0.11,\n'
#  '              "c": 0.082,\n'
#  '              "km": 0.083,\n'
#  '              "sm": 0.07,\n'
#  '              "taslak": 0.063\n'
#  '            },\n'
#  '            "macro": 0.078,\n'
#  '            "micro": 0.077\n'
#  '          },\n'
#  '          "match_rate": {\n'
#  '            "labels": {\n'
#  '              "b": 0.082,\n'
#  '              "baslag\\u0131\\u00e7": 0.227,\n'
#  '              "c": 0.117,\n'
#  '              "km": 0.093,\n'
#  '              "sm": 0.08,\n'
#  '              "taslak": 0.444\n'
#  '            },\n'
#  '            "macro": 0.174,\n'
#  '            "micro": 0.331\n'
#  '          },\n'
#  '          "pr_auc": {\n'
#  '            "labels": {\n'
#  '              "b": 0.372,\n'
#  '              "baslag\\u0131\\u00e7": 0.641,\n'
#  '              "c": 0.493,\n'
#  '              "km": 0.236,\n'
#  '              "sm": 0.322,\n'
#  '              "taslak": 0.95\n'
#  '            },\n'
#  '            "macro": 0.502,\n'
#  '            "micro": 0.781\n'
#  '          },\n'
#  '          "precision": {\n'
#  '            "labels": {\n'
#  '              "b": 0.305,\n'
#  '              "baslag\\u0131\\u00e7": 0.635,\n'
#  '              "c": 0.359,\n'
#  '              "km": 0.125,\n'
#  '              "sm": 0.14,\n'
#  '              "taslak": 0.94\n'
#  '            },\n'
#  '            "macro": 0.417,\n'
#  '            "micro": 0.755\n'
#  '          },\n'
#  '          "rates": {\n'
#  '            "population": {\n'
#  '              "b": 0.053,\n'
#  '              "baslag\\u0131\\u00e7": 0.248,\n'
#  '              "c": 0.086,\n'
#  '              "km": 0.017,\n'
#  '              "sm": 0.016,\n'
#  '              "taslak": 0.58\n'
#  '            },\n'
#  '            "sample": {\n'
#  '              "b": 0.167,\n'
#  '              "baslag\\u0131\\u00e7": 0.168,\n'
#  '              "c": 0.167,\n'
#  '              "km": 0.165,\n'
#  '              "sm": 0.167,\n'
#  '              "taslak": 0.165\n'
#  '            }\n'
#  '          },\n'
#  '          "recall": {\n'
#  '            "labels": {\n'
#  '              "b": 0.47,\n'
#  '              "baslag\\u0131\\u00e7": 0.583,\n'
#  '              "c": 0.487,\n'
#  '              "km": 0.689,\n'
#  '              "sm": 0.711,\n'
#  '              "taslak": 0.719\n'
#  '            },\n'
#  '            "macro": 0.61,\n'
#  '            "micro": 0.652\n'
#  '          },\n'
#  '          "roc_auc": {\n'
#  '            "labels": {\n'
#  '              "b": 0.856,\n'
#  '              "baslag\\u0131\\u00e7": 0.88,\n'
#  '              "c": 0.851,\n'
#  '              "km": 0.92,\n'
#  '              "sm": 0.935,\n'
#  '              "taslak": 0.947\n'
#  '            },\n'
#  '            "macro": 0.898,\n'
#  '            "micro": 0.917\n'
#  '          }\n'
#  '        },\n'
#  '        "type": "GradientBoosting",\n'
#  '        "version": "0.8.0"\n'
#  '      },\n'
#  '      "damaging": {\n'
#  '        "environment": {\n'
#  '          "machine": "x86_64",\n'
#  '          "platform": "Linux-4.9.0-11-amd64-x86_64-with-debian-9.12",\n'
#  '          "processor": "",\n'
#  '          "python_branch": "",\n'
#  '          "python_build": [\n'
#  '            "default",\n'
#  '            "Sep 27 2018 17:25:39"\n'
#  '          ],\n'
#  '          "python_compiler": "GCC 6.3.0 20170516",\n'
#  '          "python_implementation": "CPython",\n'
#  '          "python_revision": "",\n'
#  '          "python_version": "3.5.3",\n'
#  '          "release": "4.9.0-11-amd64",\n'
#  '          "revscoring_version": "2.8.0",\n'
#  '          "system": "Linux",\n'
#  '          "version": "#1 SMP Debian 4.9.189-3+deb9u1 (2019-09-20)"\n'
#  '        },\n'
#  '        "params": {\n'
#  '          "ccp_alpha": 0.0,\n'
#  '          "center": true,\n'
#  '          "criterion": "friedman_mse",\n'
#  '          "init": null,\n'
#  '          "label_weights": {\n'
#  '            "true": 10\n'
#  '          },\n'
#  '          "labels": [\n'
#  '            true,\n'
#  '            false\n'
#  '          ],\n'
#  '          "learning_rate": 0.01,\n'
#  '          "loss": "deviance",\n'
#  '          "max_depth": 7,\n'
#  '          "max_features": "log2",\n'
#  '          "max_leaf_nodes": null,\n'
#  '          "min_impurity_decrease": 0.0,\n'
#  '          "min_impurity_split": null,\n'
#  '          "min_samples_leaf": 1,\n'
#  '          "min_samples_split": 2,\n'
#  '          "min_weight_fraction_leaf": 0.0,\n'
#  '          "multilabel": false,\n'
#  '          "n_estimators": 700,\n'
#  '          "n_iter_no_change": null,\n'
#  '          "population_rates": null,\n'
#  '          "presort": "deprecated",\n'
#  '          "random_state": null,\n'
#  '          "scale": true,\n'
#  '          "subsample": 1.0,\n'
#  '          "tol": 0.0001,\n'
#  '          "validation_fraction": 0.1,\n'
#  '          "verbose": 0,\n'
#  '          "warm_start": false\n'
#  '        },\n'
#  '        "score_schema": {\n'
#  '          "properties": {\n'
#  '            "prediction": {\n'
#  '              "description": "The most likely label predicted by the estimator",\n'
#  '              "type": "boolean"\n'
#  '            },\n'
#  '            "probability": {\n'
#  '              "description": "A mapping of probabilities onto each of the potential output labels",\n'
#  '              "properties": {\n'
#  '                "false": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "true": {\n'
#  '                  "type": "number"\n'
#  '                }\n'
#  '              },\n'
#  '              "type": "object"\n'
#  '            }\n'
#  '          },\n'
#  '          "title": "Scikit learn-based classifier score with probability",\n'
#  '          "type": "object"\n'
#  '        },\n'
#  '        "statistics": {\n'
#  '          "!f1": {\n'
#  '            "labels": {\n'
#  '              "false": 0.372,\n'
#  '              "true": 0.931\n'
#  '            },\n'
#  '            "macro": 0.652,\n'
#  '            "micro": 0.4\n'
#  '          },\n'
#  '          "!precision": {\n'
#  '            "labels": {\n'
#  '              "false": 0.248,\n'
#  '              "true": 0.985\n'
#  '            },\n'
#  '            "macro": 0.617,\n'
#  '            "micro": 0.284\n'
#  '          },\n'
#  '          "!recall": {\n'
#  '            "labels": {\n'
#  '              "false": 0.747,\n'
#  '              "true": 0.882\n'
#  '            },\n'
#  '            "macro": 0.815,\n'
#  '            "micro": 0.754\n'
#  '          },\n'
#  '          "accuracy": {\n'
#  '            "labels": {\n'
#  '              "false": 0.875,\n'
#  '              "true": 0.875\n'
#  '            },\n'
#  '            "macro": 0.875,\n'
#  '            "micro": 0.875\n'
#  '          },\n'
#  '          "counts": {\n'
#  '            "labels": {\n'
#  '              "false": 18232,\n'
#  '              "true": 1087\n'
#  '            },\n'
#  '            "n": 19319,\n'
#  '            "predictions": {\n'
#  '              "false": {\n'
#  '                "false": 16081,\n'
#  '                "true": 2151\n'
#  '              },\n'
#  '              "true": {\n'
#  '                "false": 275,\n'
#  '                "true": 812\n'
#  '              }\n'
#  '            }\n'
#  '          },\n'
#  '          "f1": {\n'
#  '            "labels": {\n'
#  '              "false": 0.931,\n'
#  '              "true": 0.372\n'
#  '            },\n'
#  '            "macro": 0.652,\n'
#  '            "micro": 0.903\n'
#  '          },\n'
#  '          "filter_rate": {\n'
#  '            "labels": {\n'
#  '              "false": 0.149,\n'
#  '              "true": 0.851\n'
#  '            },\n'
#  '            "macro": 0.5,\n'
#  '            "micro": 0.184\n'
#  '          },\n'
#  '          "fpr": {\n'
#  '            "labels": {\n'
#  '              "false": 0.253,\n'
#  '              "true": 0.118\n'
#  '            },\n'
#  '            "macro": 0.185,\n'
#  '            "micro": 0.246\n'
#  '          },\n'
#  '          "match_rate": {\n'
#  '            "labels": {\n'
#  '              "false": 0.851,\n'
#  '              "true": 0.149\n'
#  '            },\n'
#  '            "macro": 0.5,\n'
#  '            "micro": 0.816\n'
#  '          },\n'
#  '          "pr_auc": {\n'
#  '            "labels": {\n'
#  '              "false": 0.995,\n'
#  '              "true": 0.314\n'
#  '            },\n'
#  '            "macro": 0.655,\n'
#  '            "micro": 0.961\n'
#  '          },\n'
#  '          "precision": {\n'
#  '            "labels": {\n'
#  '              "false": 0.985,\n'
#  '              "true": 0.248\n'
#  '            },\n'
#  '            "macro": 0.617,\n'
#  '            "micro": 0.949\n'
#  '          },\n'
#  '          "rates": {\n'
#  '            "population": {\n'
#  '              "false": 0.95,\n'
#  '              "true": 0.05\n'
#  '            },\n'
#  '            "sample": {\n'
#  '              "false": 0.944,\n'
#  '              "true": 0.056\n'
#  '            }\n'
#  '          },\n'
#  '          "recall": {\n'
#  '            "labels": {\n'
#  '              "false": 0.882,\n'
#  '              "true": 0.747\n'
#  '            },\n'
#  '            "macro": 0.815,\n'
#  '            "micro": 0.875\n'
#  '          },\n'
#  '          "roc_auc": {\n'
#  '            "labels": {\n'
#  '              "false": 0.911,\n'
#  '              "true": 0.912\n'
#  '            },\n'
#  '            "macro": 0.912,\n'
#  '            "micro": 0.911\n'
#  '          }\n'
#  '        },\n'
#  '        "type": "GradientBoosting",\n'
#  '        "version": "0.5.1"\n'
#  '      },\n'
#  '      "goodfaith": {\n'
#  '        "environment": {\n'
#  '          "machine": "x86_64",\n'
#  '          "platform": "Linux-4.9.0-11-amd64-x86_64-with-debian-9.12",\n'
#  '          "processor": "",\n'
#  '          "python_branch": "",\n'
#  '          "python_build": [\n'
#  '            "default",\n'
#  '            "Sep 27 2018 17:25:39"\n'
#  '          ],\n'
#  '          "python_compiler": "GCC 6.3.0 20170516",\n'
#  '          "python_implementation": "CPython",\n'
#  '          "python_revision": "",\n'
#  '          "python_version": "3.5.3",\n'
#  '          "release": "4.9.0-11-amd64",\n'
#  '          "revscoring_version": "2.8.0",\n'
#  '          "system": "Linux",\n'
#  '          "version": "#1 SMP Debian 4.9.189-3+deb9u1 (2019-09-20)"\n'
#  '        },\n'
#  '        "params": {\n'
#  '          "ccp_alpha": 0.0,\n'
#  '          "center": true,\n'
#  '          "criterion": "friedman_mse",\n'
#  '          "init": null,\n'
#  '          "label_weights": {\n'
#  '            "false": 10\n'
#  '          },\n'
#  '          "labels": [\n'
#  '            true,\n'
#  '            false\n'
#  '          ],\n'
#  '          "learning_rate": 0.01,\n'
#  '          "loss": "deviance",\n'
#  '          "max_depth": 7,\n'
#  '          "max_features": "log2",\n'
#  '          "max_leaf_nodes": null,\n'
#  '          "min_impurity_decrease": 0.0,\n'
#  '          "min_impurity_split": null,\n'
#  '          "min_samples_leaf": 1,\n'
#  '          "min_samples_split": 2,\n'
#  '          "min_weight_fraction_leaf": 0.0,\n'
#  '          "multilabel": false,\n'
#  '          "n_estimators": 700,\n'
#  '          "n_iter_no_change": null,\n'
#  '          "population_rates": null,\n'
#  '          "presort": "deprecated",\n'
#  '          "random_state": null,\n'
#  '          "scale": true,\n'
#  '          "subsample": 1.0,\n'
#  '          "tol": 0.0001,\n'
#  '          "validation_fraction": 0.1,\n'
#  '          "verbose": 0,\n'
#  '          "warm_start": false\n'
#  '        },\n'
#  '        "score_schema": {\n'
#  '          "properties": {\n'
#  '            "prediction": {\n'
#  '              "description": "The most likely label predicted by the estimator",\n'
#  '              "type": "boolean"\n'
#  '            },\n'
#  '            "probability": {\n'
#  '              "description": "A mapping of probabilities onto each of the potential output labels",\n'
#  '              "properties": {\n'
#  '                "false": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "true": {\n'
#  '                  "type": "number"\n'
#  '                }\n'
#  '              },\n'
#  '              "type": "object"\n'
#  '            }\n'
#  '          },\n'
#  '          "title": "Scikit learn-based classifier score with probability",\n'
#  '          "type": "object"\n'
#  '        },\n'
#  '        "statistics": {\n'
#  '          "!f1": {\n'
#  '            "labels": {\n'
#  '              "false": 0.945,\n'
#  '              "true": 0.369\n'
#  '            },\n'
#  '            "macro": 0.657,\n'
#  '            "micro": 0.396\n'
#  '          },\n'
#  '          "!precision": {\n'
#  '            "labels": {\n'
#  '              "false": 0.981,\n'
#  '              "true": 0.259\n'
#  '            },\n'
#  '            "macro": 0.62,\n'
#  '            "micro": 0.292\n'
#  '          },\n'
#  '          "!recall": {\n'
#  '            "labels": {\n'
#  '              "false": 0.911,\n'
#  '              "true": 0.644\n'
#  '            },\n'
#  '            "macro": 0.777,\n'
#  '            "micro": 0.656\n'
#  '          },\n'
#  '          "accuracy": {\n'
#  '            "labels": {\n'
#  '              "false": 0.898,\n'
#  '              "true": 0.898\n'
#  '            },\n'
#  '            "macro": 0.898,\n'
#  '            "micro": 0.898\n'
#  '          },\n'
#  '          "counts": {\n'
#  '            "labels": {\n'
#  '              "false": 820,\n'
#  '              "true": 18499\n'
#  '            },\n'
#  '            "n": 19319,\n'
#  '            "predictions": {\n'
#  '              "false": {\n'
#  '                "false": 528,\n'
#  '                "true": 292\n'
#  '              },\n'
#  '              "true": {\n'
#  '                "false": 1651,\n'
#  '                "true": 16848\n'
#  '              }\n'
#  '            }\n'
#  '          },\n'
#  '          "f1": {\n'
#  '            "labels": {\n'
#  '              "false": 0.369,\n'
#  '              "true": 0.945\n'
#  '            },\n'
#  '            "macro": 0.657,\n'
#  '            "micro": 0.918\n'
#  '          },\n'
#  '          "filter_rate": {\n'
#  '            "labels": {\n'
#  '              "false": 0.885,\n'
#  '              "true": 0.115\n'
#  '            },\n'
#  '            "macro": 0.5,\n'
#  '            "micro": 0.15\n'
#  '          },\n'
#  '          "fpr": {\n'
#  '            "labels": {\n'
#  '              "false": 0.089,\n'
#  '              "true": 0.356\n'
#  '            },\n'
#  '            "macro": 0.223,\n'
#  '            "micro": 0.344\n'
#  '          },\n'
#  '          "match_rate": {\n'
#  '            "labels": {\n'
#  '              "false": 0.115,\n'
#  '              "true": 0.885\n'
#  '            },\n'
#  '            "macro": 0.5,\n'
#  '            "micro": 0.85\n'
#  '          },\n'
#  '          "pr_auc": {\n'
#  '            "labels": {\n'
#  '              "false": 0.311,\n'
#  '              "true": 0.995\n'
#  '            },\n'
#  '            "macro": 0.653,\n'
#  '            "micro": 0.964\n'
#  '          },\n'
#  '          "precision": {\n'
#  '            "labels": {\n'
#  '              "false": 0.259,\n'
#  '              "true": 0.981\n'
#  '            },\n'
#  '            "macro": 0.62,\n'
#  '            "micro": 0.948\n'
#  '          },\n'
#  '          "rates": {\n'
#  '            "population": {\n'
#  '              "false": 0.046,\n'
#  '              "true": 0.954\n'
#  '            },\n'
#  '            "sample": {\n'
#  '              "false": 0.042,\n'
#  '              "true": 0.958\n'
#  '            }\n'
#  '          },\n'
#  '          "recall": {\n'
#  '            "labels": {\n'
#  '              "false": 0.644,\n'
#  '              "true": 0.911\n'
#  '            },\n'
#  '            "macro": 0.777,\n'
#  '            "micro": 0.898\n'
#  '          },\n'
#  '          "roc_auc": {\n'
#  '            "labels": {\n'
#  '              "false": 0.911,\n'
#  '              "true": 0.911\n'
#  '            },\n'
#  '            "macro": 0.911,\n'
#  '            "micro": 0.911\n'
#  '          }\n'
#  '        },\n'
#  '        "type": "GradientBoosting",\n'
#  '        "version": "0.5.1"\n'
#  '      },\n'
#  '      "wp10": {\n'
#  '        "environment": {\n'
#  '          "machine": "x86_64",\n'
#  '          "platform": "Linux-4.9.0-11-amd64-x86_64-with-debian-9.12",\n'
#  '          "processor": "",\n'
#  '          "python_branch": "",\n'
#  '          "python_build": [\n'
#  '            "default",\n'
#  '            "Sep 27 2018 17:25:39"\n'
#  '          ],\n'
#  '          "python_compiler": "GCC 6.3.0 20170516",\n'
#  '          "python_implementation": "CPython",\n'
#  '          "python_revision": "",\n'
#  '          "python_version": "3.5.3",\n'
#  '          "release": "4.9.0-11-amd64",\n'
#  '          "revscoring_version": "2.8.2",\n'
#  '          "system": "Linux",\n'
#  '          "version": "#1 SMP Debian 4.9.189-3+deb9u1 (2019-09-20)"\n'
#  '        },\n'
#  '        "params": {\n'
#  '          "ccp_alpha": 0.0,\n'
#  '          "center": true,\n'
#  '          "criterion": "friedman_mse",\n'
#  '          "init": null,\n'
#  '          "label_weights": null,\n'
#  '          "labels": [\n'
#  '            "taslak",\n'
#  '            "baslag\\u0131\\u00e7",\n'
#  '            "c",\n'
#  '            "b",\n'
#  '            "km",\n'
#  '            "sm"\n'
#  '          ],\n'
#  '          "learning_rate": 0.01,\n'
#  '          "loss": "deviance",\n'
#  '          "max_depth": 5,\n'
#  '          "max_features": "log2",\n'
#  '          "max_leaf_nodes": null,\n'
#  '          "min_impurity_decrease": 0.0,\n'
#  '          "min_impurity_split": null,\n'
#  '          "min_samples_leaf": 1,\n'
#  '          "min_samples_split": 2,\n'
#  '          "min_weight_fraction_leaf": 0.0,\n'
#  '          "multilabel": false,\n'
#  '          "n_estimators": 300,\n'
#  '          "n_iter_no_change": null,\n'
#  '          "population_rates": null,\n'
#  '          "presort": "deprecated",\n'
#  '          "random_state": null,\n'
#  '          "scale": true,\n'
#  '          "subsample": 1.0,\n'
#  '          "tol": 0.0001,\n'
#  '          "validation_fraction": 0.1,\n'
#  '          "verbose": 0,\n'
#  '          "warm_start": false\n'
#  '        },\n'
#  '        "score_schema": {\n'
#  '          "properties": {\n'
#  '            "prediction": {\n'
#  '              "description": "The most likely label predicted by the estimator",\n'
#  '              "type": "string"\n'
#  '            },\n'
#  '            "probability": {\n'
#  '              "description": "A mapping of probabilities onto each of the potential output labels",\n'
#  '              "properties": {\n'
#  '                "b": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "baslag\\u0131\\u00e7": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "c": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "km": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "sm": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "taslak": {\n'
#  '                  "type": "number"\n'
#  '                }\n'
#  '              },\n'
#  '              "type": "object"\n'
#  '            }\n'
#  '          },\n'
#  '          "title": "Scikit learn-based classifier score with probability",\n'
#  '          "type": "object"\n'
#  '        },\n'
#  '        "statistics": {\n'
#  '          "!f1": {\n'
#  '            "labels": {\n'
#  '              "b": 0.954,\n'
#  '              "baslag\\u0131\\u00e7": 0.878,\n'
#  '              "c": 0.934,\n'
#  '              "km": 0.954,\n'
#  '              "sm": 0.961,\n'
#  '              "taslak": 0.806\n'
#  '            },\n'
#  '            "macro": 0.915,\n'
#  '            "micro": 0.848\n'
#  '          },\n'
#  '          "!precision": {\n'
#  '            "labels": {\n'
#  '              "b": 0.969,\n'
#  '              "baslag\\u0131\\u00e7": 0.866,\n'
#  '              "c": 0.95,\n'
#  '              "km": 0.994,\n'
#  '              "sm": 0.995,\n'
#  '              "taslak": 0.707\n'
#  '            },\n'
#  '            "macro": 0.914,\n'
#  '            "micro": 0.791\n'
#  '          },\n'
#  '          "!recall": {\n'
#  '            "labels": {\n'
#  '              "b": 0.94,\n'
#  '              "baslag\\u0131\\u00e7": 0.89,\n'
#  '              "c": 0.918,\n'
#  '              "km": 0.917,\n'
#  '              "sm": 0.93,\n'
#  '              "taslak": 0.937\n'
#  '            },\n'
#  '            "macro": 0.922,\n'
#  '            "micro": 0.923\n'
#  '          },\n'
#  '          "accuracy": {\n'
#  '            "labels": {\n'
#  '              "b": 0.915,\n'
#  '              "baslag\\u0131\\u00e7": 0.814,\n'
#  '              "c": 0.881,\n'
#  '              "km": 0.913,\n'
#  '              "sm": 0.927,\n'
#  '              "taslak": 0.81\n'
#  '            },\n'
#  '            "macro": 0.877,\n'
#  '            "micro": 0.826\n'
#  '          },\n'
#  '          "counts": {\n'
#  '            "labels": {\n'
#  '              "b": 270,\n'
#  '              "baslag\\u0131\\u00e7": 271,\n'
#  '              "c": 269,\n'
#  '              "km": 267,\n'
#  '              "sm": 270,\n'
#  '              "taslak": 267\n'
#  '            },\n'
#  '            "n": 1614,\n'
#  '            "predictions": {\n'
#  '              "b": {\n'
#  '                "b": 127,\n'
#  '                "baslag\\u0131\\u00e7": 17,\n'
#  '                "c": 38,\n'
#  '                "km": 38,\n'
#  '                "sm": 45,\n'
#  '                "taslak": 5\n'
#  '              },\n'
#  '              "baslag\\u0131\\u00e7": {\n'
#  '                "b": 2,\n'
#  '                "baslag\\u0131\\u00e7": 158,\n'
#  '                "c": 43,\n'
#  '                "km": 4,\n'
#  '                "sm": 0,\n'
#  '                "taslak": 64\n'
#  '              },\n'
#  '              "c": {\n'
#  '                "b": 39,\n'
#  '                "baslag\\u0131\\u00e7": 50,\n'
#  '                "c": 131,\n'
#  '                "km": 29,\n'
#  '                "sm": 7,\n'
#  '                "taslak": 13\n'
#  '              },\n'
#  '              "km": {\n'
#  '                "b": 14,\n'
#  '                "baslag\\u0131\\u00e7": 6,\n'
#  '                "c": 20,\n'
#  '                "km": 184,\n'
#  '                "sm": 42,\n'
#  '                "taslak": 1\n'
#  '              },\n'
#  '              "sm": {\n'
#  '                "b": 26,\n'
#  '                "baslag\\u0131\\u00e7": 3,\n'
#  '                "c": 6,\n'
#  '                "km": 41,\n'
#  '                "sm": 192,\n'
#  '                "taslak": 2\n'
#  '              },\n'
#  '              "taslak": {\n'
#  '                "b": 0,\n'
#  '                "baslag\\u0131\\u00e7": 72,\n'
#  '                "c": 3,\n'
#  '                "km": 0,\n'
#  '                "sm": 0,\n'
#  '                "taslak": 192\n'
#  '              }\n'
#  '            }\n'
#  '          },\n'
#  '          "f1": {\n'
#  '            "labels": {\n'
#  '              "b": 0.37,\n'
#  '              "baslag\\u0131\\u00e7": 0.608,\n'
#  '              "c": 0.413,\n'
#  '              "km": 0.212,\n'
#  '              "sm": 0.234,\n'
#  '              "taslak": 0.815\n'
#  '            },\n'
#  '            "macro": 0.442,\n'
#  '            "micro": 0.686\n'
#  '          },\n'
#  '          "filter_rate": {\n'
#  '            "labels": {\n'
#  '              "b": 0.918,\n'
#  '              "baslag\\u0131\\u00e7": 0.773,\n'
#  '              "c": 0.883,\n'
#  '              "km": 0.907,\n'
#  '              "sm": 0.92,\n'
#  '              "taslak": 0.556\n'
#  '            },\n'
#  '            "macro": 0.826,\n'
#  '            "micro": 0.669\n'
#  '          },\n'
#  '          "fpr": {\n'
#  '            "labels": {\n'
#  '              "b": 0.06,\n'
#  '              "baslag\\u0131\\u00e7": 0.11,\n'
#  '              "c": 0.082,\n'
#  '              "km": 0.083,\n'
#  '              "sm": 0.07,\n'
#  '              "taslak": 0.063\n'
#  '            },\n'
#  '            "macro": 0.078,\n'
#  '            "micro": 0.077\n'
#  '          },\n'
#  '          "match_rate": {\n'
#  '            "labels": {\n'
#  '              "b": 0.082,\n'
#  '              "baslag\\u0131\\u00e7": 0.227,\n'
#  '              "c": 0.117,\n'
#  '              "km": 0.093,\n'
#  '              "sm": 0.08,\n'
#  '              "taslak": 0.444\n'
#  '            },\n'
#  '            "macro": 0.174,\n'
#  '            "micro": 0.331\n'
#  '          },\n'
#  '          "pr_auc": {\n'
#  '            "labels": {\n'
#  '              "b": 0.372,\n'
#  '              "baslag\\u0131\\u00e7": 0.641,\n'
#  '              "c": 0.493,\n'
#  '              "km": 0.236,\n'
#  '              "sm": 0.322,\n'
#  '              "taslak": 0.95\n'
#  '            },\n'
#  '            "macro": 0.502,\n'
#  '            "micro": 0.781\n'
#  '          },\n'
#  '          "precision": {\n'
#  '            "labels": {\n'
#  '              "b": 0.305,\n'
#  '              "baslag\\u0131\\u00e7": 0.635,\n'
#  '              "c": 0.359,\n'
#  '              "km": 0.125,\n'
#  '              "sm": 0.14,\n'
#  '              "taslak": 0.94\n'
#  '            },\n'
#  '            "macro": 0.417,\n'
#  '            "micro": 0.755\n'
#  '          },\n'
#  '          "rates": {\n'
#  '            "population": {\n'
#  '              "b": 0.053,\n'
#  '              "baslag\\u0131\\u00e7": 0.248,\n'
#  '              "c": 0.086,\n'
#  '              "km": 0.017,\n'
#  '              "sm": 0.016,\n'
#  '              "taslak": 0.58\n'
#  '            },\n'
#  '            "sample": {\n'
#  '              "b": 0.167,\n'
#  '              "baslag\\u0131\\u00e7": 0.168,\n'
#  '              "c": 0.167,\n'
#  '              "km": 0.165,\n'
#  '              "sm": 0.167,\n'
#  '              "taslak": 0.165\n'
#  '            }\n'
#  '          },\n'
#  '          "recall": {\n'
#  '            "labels": {\n'
#  '              "b": 0.47,\n'
#  '              "baslag\\u0131\\u00e7": 0.583,\n'
#  '              "c": 0.487,\n'
#  '              "km": 0.689,\n'
#  '              "sm": 0.711,\n'
#  '              "taslak": 0.719\n'
#  '            },\n'
#  '            "macro": 0.61,\n'
#  '            "micro": 0.652\n'
#  '          },\n'
#  '          "roc_auc": {\n'
#  '            "labels": {\n'
#  '              "b": 0.856,\n'
#  '              "baslag\\u0131\\u00e7": 0.88,\n'
#  '              "c": 0.851,\n'
#  '              "km": 0.92,\n'
#  '              "sm": 0.935,\n'
#  '              "taslak": 0.947\n'
#  '            },\n'
#  '            "macro": 0.898,\n'
#  '            "micro": 0.917\n'
#  '          }\n'
#  '        },\n'
#  '        "type": "GradientBoosting",\n'
#  '        "version": "0.8.0"\n'
#  '      }\n'
#  '    }\n'
#  '  },\n'
#  '  "ukwiki": {\n'
#  '    "models": {\n'
#  '      "articlequality": {\n'
#  '        "environment": {\n'
#  '          "machine": "x86_64",\n'
#  '          "platform": "Linux-4.9.0-8-amd64-x86_64-with-debian-9.4",\n'
#  '          "processor": "",\n'
#  '          "python_branch": "",\n'
#  '          "python_build": [\n'
#  '            "default",\n'
#  '            "Sep 27 2018 17:25:39"\n'
#  '          ],\n'
#  '          "python_compiler": "GCC 6.3.0 20170516",\n'
#  '          "python_implementation": "CPython",\n'
#  '          "python_revision": "",\n'
#  '          "python_version": "3.5.3",\n'
#  '          "release": "4.9.0-8-amd64",\n'
#  '          "revscoring_version": "2.8.2",\n'
#  '          "system": "Linux",\n'
#  '          "version": "#1 SMP Debian 4.9.144-3.1 (2019-02-19)"\n'
#  '        },\n'
#  '        "params": {\n'
#  '          "ccp_alpha": 0.0,\n'
#  '          "center": true,\n'
#  '          "criterion": "friedman_mse",\n'
#  '          "init": null,\n'
#  '          "label_weights": null,\n'
#  '          "labels": [\n'
#  '            "IV",\n'
#  '            "III",\n'
#  '            "II",\n'
#  '            "I",\n'
#  '            "\\u0414\\u0421",\n'
#  '            "\\u0412\\u0421"\n'
#  '          ],\n'
#  '          "learning_rate": 0.01,\n'
#  '          "loss": "deviance",\n'
#  '          "max_depth": 7,\n'
#  '          "max_features": "log2",\n'
#  '          "max_leaf_nodes": null,\n'
#  '          "min_impurity_decrease": 0.0,\n'
#  '          "min_impurity_split": null,\n'
#  '          "min_samples_leaf": 1,\n'
#  '          "min_samples_split": 2,\n'
#  '          "min_weight_fraction_leaf": 0.0,\n'
#  '          "multilabel": false,\n'
#  '          "n_estimators": 500,\n'
#  '          "n_iter_no_change": null,\n'
#  '          "population_rates": null,\n'
#  '          "presort": "deprecated",\n'
#  '          "random_state": null,\n'
#  '          "scale": true,\n'
#  '          "subsample": 1.0,\n'
#  '          "tol": 0.0001,\n'
#  '          "validation_fraction": 0.1,\n'
#  '          "verbose": 0,\n'
#  '          "warm_start": false\n'
#  '        },\n'
#  '        "score_schema": {\n'
#  '          "properties": {\n'
#  '            "prediction": {\n'
#  '              "description": "The most likely label predicted by the estimator",\n'
#  '              "type": "string"\n'
#  '            },\n'
#  '            "probability": {\n'
#  '              "description": "A mapping of probabilities onto each of the potential output labels",\n'
#  '              "properties": {\n'
#  '                "I": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "II": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "III": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "IV": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "\\u0412\\u0421": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "\\u0414\\u0421": {\n'
#  '                  "type": "number"\n'
#  '                }\n'
#  '              },\n'
#  '              "type": "object"\n'
#  '            }\n'
#  '          },\n'
#  '          "title": "Scikit learn-based classifier score with probability",\n'
#  '          "type": "object"\n'
#  '        },\n'
#  '        "statistics": {\n'
#  '          "!f1": {\n'
#  '            "labels": {\n'
#  '              "I": 0.917,\n'
#  '              "II": 0.884,\n'
#  '              "III": 0.607,\n'
#  '              "IV": 0.875,\n'
#  '              "\\u0412\\u0421": 0.955,\n'
#  '              "\\u0414\\u0421": 0.946\n'
#  '            },\n'
#  '            "macro": 0.864,\n'
#  '            "micro": 0.715\n'
#  '          },\n'
#  '          "!precision": {\n'
#  '            "labels": {\n'
#  '              "I": 0.987,\n'
#  '              "II": 0.931,\n'
#  '              "III": 0.461,\n'
#  '              "IV": 0.845,\n'
#  '              "\\u0412\\u0421": 0.998,\n'
#  '              "\\u0414\\u0421": 0.993\n'
#  '            },\n'
#  '            "macro": 0.869,\n'
#  '            "micro": 0.625\n'
#  '          },\n'
#  '          "!recall": {\n'
#  '            "labels": {\n'
#  '              "I": 0.857,\n'
#  '              "II": 0.841,\n'
#  '              "III": 0.891,\n'
#  '              "IV": 0.907,\n'
#  '              "\\u0412\\u0421": 0.916,\n'
#  '              "\\u0414\\u0421": 0.904\n'
#  '            },\n'
#  '            "macro": 0.886,\n'
#  '            "micro": 0.89\n'
#  '          },\n'
#  '          "accuracy": {\n'
#  '            "labels": {\n'
#  '              "I": 0.848,\n'
#  '              "II": 0.8,\n'
#  '              "III": 0.551,\n'
#  '              "IV": 0.809,\n'
#  '              "\\u0412\\u0421": 0.914,\n'
#  '              "\\u0414\\u0421": 0.899\n'
#  '            },\n'
#  '            "macro": 0.804,\n'
#  '            "micro": 0.654\n'
#  '          },\n'
#  '          "counts": {\n'
#  '            "labels": {\n'
#  '              "I": 150,\n'
#  '              "II": 149,\n'
#  '              "III": 150,\n'
#  '              "IV": 150,\n'
#  '              "\\u0412\\u0421": 150,\n'
#  '              "\\u0414\\u0421": 150\n'
#  '            },\n'
#  '            "n": 899,\n'
#  '            "predictions": {\n'
#  '              "I": {\n'
#  '                "I": 56,\n'
#  '                "II": 36,\n'
#  '                "III": 12,\n'
#  '                "IV": 6,\n'
#  '                "\\u0412\\u0421": 16,\n'
#  '                "\\u0414\\u0421": 24\n'
#  '              },\n'
#  '              "II": {\n'
#  '                "I": 34,\n'
#  '                "II": 63,\n'
#  '                "III": 20,\n'
#  '                "IV": 21,\n'
#  '                "\\u0412\\u0421": 5,\n'
#  '                "\\u0414\\u0421": 6\n'
#  '              },\n'
#  '              "III": {\n'
#  '                "I": 10,\n'
#  '                "II": 42,\n'
#  '                "III": 50,\n'
#  '                "IV": 43,\n'
#  '                "\\u0412\\u0421": 2,\n'
#  '                "\\u0414\\u0421": 3\n'
#  '              },\n'
#  '              "IV": {\n'
#  '                "I": 5,\n'
#  '                "II": 19,\n'
#  '                "III": 45,\n'
#  '                "IV": 81,\n'
#  '                "\\u0412\\u0421": 0,\n'
#  '                "\\u0414\\u0421": 0\n'
#  '              },\n'
#  '              "\\u0412\\u0421": {\n'
#  '                "I": 18,\n'
#  '                "II": 11,\n'
#  '                "III": 2,\n'
#  '                "IV": 0,\n'
#  '                "\\u0412\\u0421": 80,\n'
#  '                "\\u0414\\u0421": 39\n'
#  '              },\n'
#  '              "\\u0414\\u0421": {\n'
#  '                "I": 40,\n'
#  '                "II": 11,\n'
#  '                "III": 3,\n'
#  '                "IV": 0,\n'
#  '                "\\u0412\\u0421": 40,\n'
#  '                "\\u0414\\u0421": 56\n'
#  '              }\n'
#  '            }\n'
#  '          },\n'
#  '          "f1": {\n'
#  '            "labels": {\n'
#  '              "I": 0.081,\n'
#  '              "II": 0.293,\n'
#  '              "III": 0.475,\n'
#  '              "IV": 0.601,\n'
#  '              "\\u0412\\u0421": 0.049,\n'
#  '              "\\u0414\\u0421": 0.068\n'
#  '            },\n'
#  '            "macro": 0.261,\n'
#  '            "micro": 0.478\n'
#  '          },\n'
#  '          "filter_rate": {\n'
#  '            "labels": {\n'
#  '              "I": 0.853,\n'
#  '              "II": 0.815,\n'
#  '              "III": 0.754,\n'
#  '              "IV": 0.788,\n'
#  '              "\\u0412\\u0421": 0.914,\n'
#  '              "\\u0414\\u0421": 0.901\n'
#  '            },\n'
#  '            "macro": 0.838,\n'
#  '            "micro": 0.773\n'
#  '          },\n'
#  '          "fpr": {\n'
#  '            "labels": {\n'
#  '              "I": 0.143,\n'
#  '              "II": 0.159,\n'
#  '              "III": 0.109,\n'
#  '              "IV": 0.093,\n'
#  '              "\\u0412\\u0421": 0.084,\n'
#  '              "\\u0414\\u0421": 0.096\n'
#  '            },\n'
#  '            "macro": 0.114,\n'
#  '            "micro": 0.11\n'
#  '          },\n'
#  '          "match_rate": {\n'
#  '            "labels": {\n'
#  '              "I": 0.147,\n'
#  '              "II": 0.185,\n'
#  '              "III": 0.246,\n'
#  '              "IV": 0.212,\n'
#  '              "\\u0412\\u0421": 0.086,\n'
#  '              "\\u0414\\u0421": 0.099\n'
#  '            },\n'
#  '            "macro": 0.162,\n'
#  '            "micro": 0.227\n'
#  '          },\n'
#  '          "pr_auc": {\n'
#  '            "labels": {\n'
#  '              "I": 0.058,\n'
#  '              "II": 0.217,\n'
#  '              "III": 0.795,\n'
#  '              "IV": 0.713,\n'
#  '              "\\u0412\\u0421": 0.052,\n'
#  '              "\\u0414\\u0421": 0.05\n'
#  '            },\n'
#  '            "macro": 0.314,\n'
#  '            "micro": 0.693\n'
#  '          },\n'
#  '          "precision": {\n'
#  '            "labels": {\n'
#  '              "I": 0.046,\n'
#  '              "II": 0.224,\n'
#  '              "III": 0.826,\n'
#  '              "IV": 0.676,\n'
#  '              "\\u0412\\u0421": 0.026,\n'
#  '              "\\u0414\\u0421": 0.037\n'
#  '            },\n'
#  '            "macro": 0.306,\n'
#  '            "micro": 0.703\n'
#  '          },\n'
#  '          "rates": {\n'
#  '            "population": {\n'
#  '              "I": 0.018,\n'
#  '              "II": 0.098,\n'
#  '              "III": 0.61,\n'
#  '              "IV": 0.266,\n'
#  '              "\\u0412\\u0421": 0.004,\n'
#  '              "\\u0414\\u0421": 0.01\n'
#  '            },\n'
#  '            "sample": {\n'
#  '              "I": 0.167,\n'
#  '              "II": 0.166,\n'
#  '              "III": 0.167,\n'
#  '              "IV": 0.167,\n'
#  '              "\\u0412\\u0421": 0.167,\n'
#  '              "\\u0414\\u0421": 0.167\n'
#  '            }\n'
#  '          },\n'
#  '          "recall": {\n'
#  '            "labels": {\n'
#  '              "I": 0.373,\n'
#  '              "II": 0.423,\n'
#  '              "III": 0.333,\n'
#  '              "IV": 0.54,\n'
#  '              "\\u0412\\u0421": 0.533,\n'
#  '              "\\u0414\\u0421": 0.373\n'
#  '            },\n'
#  '            "macro": 0.429,\n'
#  '            "micro": 0.399\n'
#  '          },\n'
#  '          "roc_auc": {\n'
#  '            "labels": {\n'
#  '              "I": 0.747,\n'
#  '              "II": 0.733,\n'
#  '              "III": 0.791,\n'
#  '              "IV": 0.874,\n'
#  '              "\\u0412\\u0421": 0.893,\n'
#  '              "\\u0414\\u0421": 0.842\n'
#  '            },\n'
#  '            "macro": 0.813,\n'
#  '            "micro": 0.807\n'
#  '          }\n'
#  '        },\n'
#  '        "type": "GradientBoosting",\n'
#  '        "version": "0.8.0"\n'
#  '      },\n'
#  '      "damaging": {\n'
#  '        "environment": {\n'
#  '          "machine": "x86_64",\n'
#  '          "platform": "Linux-4.9.0-11-amd64-x86_64-with-debian-9.12",\n'
#  '          "processor": "",\n'
#  '          "python_branch": "",\n'
#  '          "python_build": [\n'
#  '            "default",\n'
#  '            "Sep 27 2018 17:25:39"\n'
#  '          ],\n'
#  '          "python_compiler": "GCC 6.3.0 20170516",\n'
#  '          "python_implementation": "CPython",\n'
#  '          "python_revision": "",\n'
#  '          "python_version": "3.5.3",\n'
#  '          "release": "4.9.0-11-amd64",\n'
#  '          "revscoring_version": "2.8.2",\n'
#  '          "system": "Linux",\n'
#  '          "version": "#1 SMP Debian 4.9.189-3+deb9u1 (2019-09-20)"\n'
#  '        },\n'
#  '        "params": {\n'
#  '          "ccp_alpha": 0.0,\n'
#  '          "center": true,\n'
#  '          "criterion": "friedman_mse",\n'
#  '          "init": null,\n'
#  '          "label_weights": {\n'
#  '            "true": 10\n'
#  '          },\n'
#  '          "labels": [\n'
#  '            true,\n'
#  '            false\n'
#  '          ],\n'
#  '          "learning_rate": 0.01,\n'
#  '          "loss": "deviance",\n'
#  '          "max_depth": 5,\n'
#  '          "max_features": "log2",\n'
#  '          "max_leaf_nodes": null,\n'
#  '          "min_impurity_decrease": 0.0,\n'
#  '          "min_impurity_split": null,\n'
#  '          "min_samples_leaf": 1,\n'
#  '          "min_samples_split": 2,\n'
#  '          "min_weight_fraction_leaf": 0.0,\n'
#  '          "multilabel": false,\n'
#  '          "n_estimators": 700,\n'
#  '          "n_iter_no_change": null,\n'
#  '          "population_rates": null,\n'
#  '          "presort": "deprecated",\n'
#  '          "random_state": null,\n'
#  '          "scale": true,\n'
#  '          "subsample": 1.0,\n'
#  '          "tol": 0.0001,\n'
#  '          "validation_fraction": 0.1,\n'
#  '          "verbose": 0,\n'
#  '          "warm_start": false\n'
#  '        },\n'
#  '        "score_schema": {\n'
#  '          "properties": {\n'
#  '            "prediction": {\n'
#  '              "description": "The most likely label predicted by the estimator",\n'
#  '              "type": "boolean"\n'
#  '            },\n'
#  '            "probability": {\n'
#  '              "description": "A mapping of probabilities onto each of the potential output labels",\n'
#  '              "properties": {\n'
#  '                "false": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "true": {\n'
#  '                  "type": "number"\n'
#  '                }\n'
#  '              },\n'
#  '              "type": "object"\n'
#  '            }\n'
#  '          },\n'
#  '          "title": "Scikit learn-based classifier score with probability",\n'
#  '          "type": "object"\n'
#  '        },\n'
#  '        "statistics": {\n'
#  '          "!f1": {\n'
#  '            "labels": {\n'
#  '              "false": 0.352,\n'
#  '              "true": 0.973\n'
#  '            },\n'
#  '            "macro": 0.663,\n'
#  '            "micro": 0.366\n'
#  '          },\n'
#  '          "!precision": {\n'
#  '            "labels": {\n'
#  '              "false": 0.244,\n'
#  '              "true": 0.991\n'
#  '            },\n'
#  '            "macro": 0.618,\n'
#  '            "micro": 0.261\n'
#  '          },\n'
#  '          "!recall": {\n'
#  '            "labels": {\n'
#  '              "false": 0.636,\n'
#  '              "true": 0.955\n'
#  '            },\n'
#  '            "macro": 0.795,\n'
#  '            "micro": 0.643\n'
#  '          },\n'
#  '          "accuracy": {\n'
#  '            "labels": {\n'
#  '              "false": 0.947,\n'
#  '              "true": 0.947\n'
#  '            },\n'
#  '            "macro": 0.947,\n'
#  '            "micro": 0.947\n'
#  '          },\n'
#  '          "counts": {\n'
#  '            "labels": {\n'
#  '              "false": 18688,\n'
#  '              "true": 434\n'
#  '            },\n'
#  '            "n": 19122,\n'
#  '            "predictions": {\n'
#  '              "false": {\n'
#  '                "false": 17840,\n'
#  '                "true": 848\n'
#  '              },\n'
#  '              "true": {\n'
#  '                "false": 158,\n'
#  '                "true": 276\n'
#  '              }\n'
#  '            }\n'
#  '          },\n'
#  '          "f1": {\n'
#  '            "labels": {\n'
#  '              "false": 0.973,\n'
#  '              "true": 0.352\n'
#  '            },\n'
#  '            "macro": 0.663,\n'
#  '            "micro": 0.959\n'
#  '          },\n'
#  '          "filter_rate": {\n'
#  '            "labels": {\n'
#  '              "false": 0.059,\n'
#  '              "true": 0.941\n'
#  '            },\n'
#  '            "macro": 0.5,\n'
#  '            "micro": 0.079\n'
#  '          },\n'
#  '          "fpr": {\n'
#  '            "labels": {\n'
#  '              "false": 0.364,\n'
#  '              "true": 0.045\n'
#  '            },\n'
#  '            "macro": 0.205,\n'
#  '            "micro": 0.357\n'
#  '          },\n'
#  '          "match_rate": {\n'
#  '            "labels": {\n'
#  '              "false": 0.941,\n'
#  '              "true": 0.059\n'
#  '            },\n'
#  '            "macro": 0.5,\n'
#  '            "micro": 0.921\n'
#  '          },\n'
#  '          "pr_auc": {\n'
#  '            "labels": {\n'
#  '              "false": 0.999,\n'
#  '              "true": 0.336\n'
#  '            },\n'
#  '            "macro": 0.667,\n'
#  '            "micro": 0.984\n'
#  '          },\n'
#  '          "precision": {\n'
#  '            "labels": {\n'
#  '              "false": 0.991,\n'
#  '              "true": 0.244\n'
#  '            },\n'
#  '            "macro": 0.618,\n'
#  '            "micro": 0.974\n'
#  '          },\n'
#  '          "rates": {\n'
#  '            "population": {\n'
#  '              "false": 0.978,\n'
#  '              "true": 0.022\n'
#  '            },\n'
#  '            "sample": {\n'
#  '              "false": 0.977,\n'
#  '              "true": 0.023\n'
#  '            }\n'
#  '          },\n'
#  '          "recall": {\n'
#  '            "labels": {\n'
#  '              "false": 0.955,\n'
#  '              "true": 0.636\n'
#  '            },\n'
#  '            "macro": 0.795,\n'
#  '            "micro": 0.947\n'
#  '          },\n'
#  '          "roc_auc": {\n'
#  '            "labels": {\n'
#  '              "false": 0.949,\n'
#  '              "true": 0.951\n'
#  '            },\n'
#  '            "macro": 0.95,\n'
#  '            "micro": 0.949\n'
#  '          }\n'
#  '        },\n'
#  '        "type": "GradientBoosting",\n'
#  '        "version": "0.5.1"\n'
#  '      },\n'
#  '      "goodfaith": {\n'
#  '        "environment": {\n'
#  '          "machine": "x86_64",\n'
#  '          "platform": "Linux-4.9.0-11-amd64-x86_64-with-debian-9.12",\n'
#  '          "processor": "",\n'
#  '          "python_branch": "",\n'
#  '          "python_build": [\n'
#  '            "default",\n'
#  '            "Sep 27 2018 17:25:39"\n'
#  '          ],\n'
#  '          "python_compiler": "GCC 6.3.0 20170516",\n'
#  '          "python_implementation": "CPython",\n'
#  '          "python_revision": "",\n'
#  '          "python_version": "3.5.3",\n'
#  '          "release": "4.9.0-11-amd64",\n'
#  '          "revscoring_version": "2.8.2",\n'
#  '          "system": "Linux",\n'
#  '          "version": "#1 SMP Debian 4.9.189-3+deb9u1 (2019-09-20)"\n'
#  '        },\n'
#  '        "params": {\n'
#  '          "ccp_alpha": 0.0,\n'
#  '          "center": true,\n'
#  '          "criterion": "friedman_mse",\n'
#  '          "init": null,\n'
#  '          "label_weights": {\n'
#  '            "false": 10\n'
#  '          },\n'
#  '          "labels": [\n'
#  '            true,\n'
#  '            false\n'
#  '          ],\n'
#  '          "learning_rate": 0.01,\n'
#  '          "loss": "deviance",\n'
#  '          "max_depth": 5,\n'
#  '          "max_features": "log2",\n'
#  '          "max_leaf_nodes": null,\n'
# ...
#  '                "D": 1722,\n'
#  '                "E": 147\n'
#  '              },\n'
#  '              "E": {\n'
#  '                "A": 0,\n'
#  '                "B": 0,\n'
#  '                "C": 3,\n'
#  '                "D": 87,\n'
#  '                "E": 2937\n'
#  '              }\n'
#  '            }\n'
#  '          },\n'
#  '          "f1": {\n'
#  '            "labels": {\n'
#  '              "A": 0.858,\n'
#  '              "B": 0.636,\n'
#  '              "C": 0.854,\n'
#  '              "D": 0.873,\n'
#  '              "E": 0.96\n'
#  '            },\n'
#  '            "macro": 0.836,\n'
#  '            "micro": 0.875\n'
#  '          },\n'
#  '          "filter_rate": {\n'
#  '            "labels": {\n'
#  '              "A": 0.899,\n'
#  '              "B": 0.927,\n'
#  '              "C": 0.735,\n'
#  '              "D": 0.783,\n'
#  '              "E": 0.656\n'
#  '            },\n'
#  '            "macro": 0.8,\n'
#  '            "micro": 0.752\n'
#  '          },\n'
#  '          "fpr": {\n'
#  '            "labels": {\n'
#  '              "A": 0.017,\n'
#  '              "B": 0.024,\n'
#  '              "C": 0.058,\n'
#  '              "D": 0.033,\n'
#  '              "E": 0.026\n'
#  '            },\n'
#  '            "macro": 0.031,\n'
#  '            "micro": 0.034\n'
#  '          },\n'
#  '          "match_rate": {\n'
#  '            "labels": {\n'
#  '              "A": 0.101,\n'
#  '              "B": 0.073,\n'
#  '              "C": 0.265,\n'
#  '              "D": 0.217,\n'
#  '              "E": 0.344\n'
#  '            },\n'
#  '            "macro": 0.2,\n'
#  '            "micro": 0.248\n'
#  '          },\n'
#  '          "pr_auc": {\n'
#  '            "labels": {\n'
#  '              "A": 0.895,\n'
#  '              "B": 0.715,\n'
#  '              "C": 0.91,\n'
#  '              "D": 0.914,\n'
#  '              "E": 0.986\n'
#  '            },\n'
#  '            "macro": 0.884,\n'
#  '            "micro": 0.918\n'
#  '          },\n'
#  '          "precision": {\n'
#  '            "labels": {\n'
#  '              "A": 0.851,\n'
#  '              "B": 0.699,\n'
#  '              "C": 0.837,\n'
#  '              "D": 0.883,\n'
#  '              "E": 0.95\n'
#  '            },\n'
#  '            "macro": 0.844,\n'
#  '            "micro": 0.875\n'
#  '          },\n'
#  '          "rates": {\n'
#  '            "sample": {\n'
#  '              "A": 0.1,\n'
#  '              "B": 0.087,\n'
#  '              "C": 0.254,\n'
#  '              "D": 0.222,\n'
#  '              "E": 0.337\n'
#  '            }\n'
#  '          },\n'
#  '          "recall": {\n'
#  '            "labels": {\n'
#  '              "A": 0.865,\n'
#  '              "B": 0.584,\n'
#  '              "C": 0.872,\n'
#  '              "D": 0.864,\n'
#  '              "E": 0.97\n'
#  '            },\n'
#  '            "macro": 0.831,\n'
#  '            "micro": 0.877\n'
#  '          },\n'
#  '          "roc_auc": {\n'
#  '            "labels": {\n'
#  '              "A": 0.981,\n'
#  '              "B": 0.953,\n'
#  '              "C": 0.968,\n'
#  '              "D": 0.972,\n'
#  '              "E": 0.988\n'
#  '            },\n'
#  '            "macro": 0.972,\n'
#  '            "micro": 0.976\n'
#  '          }\n'
#  '        },\n'
#  '        "type": "GradientBoosting",\n'
#  '        "version": "0.5.0"\n'
#  '      }\n'
#  '    }\n'
#  '  },\n'
#  '  "zhwiki": {\n'
#  '    "models": {\n'
#  '      "damaging": {\n'
#  '        "environment": {\n'
#  '          "machine": "x86_64",\n'
#  '          "platform": "Linux-4.9.0-11-amd64-x86_64-with-debian-9.12",\n'
#  '          "processor": "",\n'
#  '          "python_branch": "",\n'
#  '          "python_build": [\n'
#  '            "default",\n'
#  '            "Sep 27 2018 17:25:39"\n'
#  '          ],\n'
#  '          "python_compiler": "GCC 6.3.0 20170516",\n'
#  '          "python_implementation": "CPython",\n'
#  '          "python_revision": "",\n'
#  '          "python_version": "3.5.3",\n'
#  '          "release": "4.9.0-11-amd64",\n'
#  '          "revscoring_version": "2.8.0",\n'
#  '          "system": "Linux",\n'
#  '          "version": "#1 SMP Debian 4.9.189-3+deb9u1 (2019-09-20)"\n'
#  '        },\n'
#  '        "params": {\n'
#  '          "ccp_alpha": 0.0,\n'
#  '          "center": true,\n'
#  '          "criterion": "friedman_mse",\n'
#  '          "init": null,\n'
#  '          "label_weights": {\n'
#  '            "true": 10\n'
#  '          },\n'
#  '          "labels": [\n'
#  '            true,\n'
#  '            false\n'
#  '          ],\n'
#  '          "learning_rate": 0.01,\n'
#  '          "loss": "deviance",\n'
#  '          "max_depth": 3,\n'
#  '          "max_features": "log2",\n'
#  '          "max_leaf_nodes": null,\n'
#  '          "min_impurity_decrease": 0.0,\n'
#  '          "min_impurity_split": null,\n'
#  '          "min_samples_leaf": 7,\n'
#  '          "min_samples_split": 2,\n'
#  '          "min_weight_fraction_leaf": 0.0,\n'
#  '          "multilabel": false,\n'
#  '          "n_estimators": 700,\n'
#  '          "n_iter_no_change": null,\n'
#  '          "population_rates": null,\n'
#  '          "presort": "deprecated",\n'
#  '          "random_state": null,\n'
#  '          "scale": true,\n'
#  '          "subsample": 1.0,\n'
#  '          "tol": 0.0001,\n'
#  '          "validation_fraction": 0.1,\n'
#  '          "verbose": 0,\n'
#  '          "warm_start": false\n'
#  '        },\n'
#  '        "score_schema": {\n'
#  '          "properties": {\n'
#  '            "prediction": {\n'
#  '              "description": "The most likely label predicted by the estimator",\n'
#  '              "type": "boolean"\n'
#  '            },\n'
#  '            "probability": {\n'
#  '              "description": "A mapping of probabilities onto each of the potential output labels",\n'
#  '              "properties": {\n'
#  '                "false": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "true": {\n'
#  '                  "type": "number"\n'
#  '                }\n'
#  '              },\n'
#  '              "type": "object"\n'
#  '            }\n'
#  '          },\n'
#  '          "title": "Scikit learn-based classifier score with probability",\n'
#  '          "type": "object"\n'
#  '        },\n'
#  '        "statistics": {\n'
#  '          "!f1": {\n'
#  '            "labels": {\n'
#  '              "false": 0.5,\n'
#  '              "true": 0.982\n'
#  '            },\n'
#  '            "macro": 0.741,\n'
#  '            "micro": 0.52\n'
#  '          },\n'
#  '          "!precision": {\n'
#  '            "labels": {\n'
#  '              "false": 0.617,\n'
#  '              "true": 0.976\n'
#  '            },\n'
#  '            "macro": 0.796,\n'
#  '            "micro": 0.631\n'
#  '          },\n'
#  '          "!recall": {\n'
#  '            "labels": {\n'
#  '              "false": 0.42,\n'
#  '              "true": 0.989\n'
#  '            },\n'
#  '            "macro": 0.705,\n'
#  '            "micro": 0.443\n'
#  '          },\n'
#  '          "accuracy": {\n'
#  '            "labels": {\n'
#  '              "false": 0.966,\n'
#  '              "true": 0.966\n'
#  '            },\n'
#  '            "macro": 0.966,\n'
#  '            "micro": 0.966\n'
#  '          },\n'
#  '          "counts": {\n'
#  '            "labels": {\n'
#  '              "false": 68439,\n'
#  '              "true": 352\n'
#  '            },\n'
#  '            "n": 68791,\n'
#  '            "predictions": {\n'
#  '              "false": {\n'
#  '                "false": 67684,\n'
#  '                "true": 755\n'
#  '              },\n'
#  '              "true": {\n'
#  '                "false": 204,\n'
#  '                "true": 148\n'
#  '              }\n'
#  '            }\n'
#  '          },\n'
#  '          "f1": {\n'
#  '            "labels": {\n'
#  '              "false": 0.982,\n'
#  '              "true": 0.5\n'
#  '            },\n'
#  '            "macro": 0.741,\n'
#  '            "micro": 0.963\n'
#  '          },\n'
#  '          "filter_rate": {\n'
#  '            "labels": {\n'
#  '              "false": 0.028,\n'
#  '              "true": 0.972\n'
#  '            },\n'
#  '            "macro": 0.5,\n'
#  '            "micro": 0.066\n'
#  '          },\n'
#  '          "fpr": {\n'
#  '            "labels": {\n'
#  '              "false": 0.58,\n'
#  '              "true": 0.011\n'
#  '            },\n'
#  '            "macro": 0.295,\n'
#  '            "micro": 0.557\n'
#  '          },\n'
#  '          "match_rate": {\n'
#  '            "labels": {\n'
#  '              "false": 0.972,\n'
#  '              "true": 0.028\n'
#  '            },\n'
#  '            "macro": 0.5,\n'
#  '            "micro": 0.934\n'
#  '          },\n'
#  '          "pr_auc": {\n'
#  '            "labels": {\n'
#  '              "false": 0.992,\n'
#  '              "true": 0.457\n'
#  '            },\n'
#  '            "macro": 0.725,\n'
#  '            "micro": 0.971\n'
#  '          },\n'
#  '          "precision": {\n'
#  '            "labels": {\n'
#  '              "false": 0.976,\n'
#  '              "true": 0.617\n'
#  '            },\n'
#  '            "macro": 0.796,\n'
#  '            "micro": 0.961\n'
#  '          },\n'
#  '          "rates": {\n'
#  '            "population": {\n'
#  '              "false": 0.96,\n'
#  '              "true": 0.04\n'
#  '            },\n'
#  '            "sample": {\n'
#  '              "false": 0.995,\n'
#  '              "true": 0.005\n'
#  '            }\n'
#  '          },\n'
#  '          "recall": {\n'
#  '            "labels": {\n'
#  '              "false": 0.989,\n'
#  '              "true": 0.42\n'
#  '            },\n'
#  '            "macro": 0.705,\n'
#  '            "micro": 0.966\n'
#  '          },\n'
#  '          "roc_auc": {\n'
#  '            "labels": {\n'
#  '              "false": 0.878,\n'
#  '              "true": 0.876\n'
#  '            },\n'
#  '            "macro": 0.877,\n'
#  '            "micro": 0.877\n'
#  '          }\n'
#  '        },\n'
#  '        "type": "GradientBoosting",\n'
#  '        "version": "0.5.0"\n'
#  '      },\n'
#  '      "goodfaith": {\n'
#  '        "environment": {\n'
#  '          "machine": "x86_64",\n'
#  '          "platform": "Linux-4.9.0-11-amd64-x86_64-with-debian-9.12",\n'
#  '          "processor": "",\n'
#  '          "python_branch": "",\n'
#  '          "python_build": [\n'
#  '            "default",\n'
#  '            "Sep 27 2018 17:25:39"\n'
#  '          ],\n'
#  '          "python_compiler": "GCC 6.3.0 20170516",\n'
#  '          "python_implementation": "CPython",\n'
#  '          "python_revision": "",\n'
#  '          "python_version": "3.5.3",\n'
#  '          "release": "4.9.0-11-amd64",\n'
#  '          "revscoring_version": "2.8.0",\n'
#  '          "system": "Linux",\n'
#  '          "version": "#1 SMP Debian 4.9.189-3+deb9u1 (2019-09-20)"\n'
#  '        },\n'
#  '        "params": {\n'
#  '          "ccp_alpha": 0.0,\n'
#  '          "center": true,\n'
#  '          "criterion": "friedman_mse",\n'
#  '          "init": null,\n'
#  '          "label_weights": {\n'
#  '            "false": 10\n'
#  '          },\n'
#  '          "labels": [\n'
#  '            true,\n'
#  '            false\n'
#  '          ],\n'
#  '          "learning_rate": 0.01,\n'
#  '          "loss": "deviance",\n'
#  '          "max_depth": 3,\n'
#  '          "max_features": "log2",\n'
#  '          "max_leaf_nodes": null,\n'
#  '          "min_impurity_decrease": 0.0,\n'
#  '          "min_impurity_split": null,\n'
#  '          "min_samples_leaf": 5,\n'
#  '          "min_samples_split": 2,\n'
#  '          "min_weight_fraction_leaf": 0.0,\n'
#  '          "multilabel": false,\n'
#  '          "n_estimators": 500,\n'
#  '          "n_iter_no_change": null,\n'
#  '          "population_rates": null,\n'
#  '          "presort": "deprecated",\n'
#  '          "random_state": null,\n'
#  '          "scale": true,\n'
#  '          "subsample": 1.0,\n'
#  '          "tol": 0.0001,\n'
#  '          "validation_fraction": 0.1,\n'
#  '          "verbose": 0,\n'
#  '          "warm_start": false\n'
#  '        },\n'
#  '        "score_schema": {\n'
#  '          "properties": {\n'
#  '            "prediction": {\n'
#  '              "description": "The most likely label predicted by the estimator",\n'
#  '              "type": "boolean"\n'
#  '            },\n'
#  '            "probability": {\n'
#  '              "description": "A mapping of probabilities onto each of the potential output labels",\n'
#  '              "properties": {\n'
#  '                "false": {\n'
#  '                  "type": "number"\n'
#  '                },\n'
#  '                "true": {\n'
#  '                  "type": "number"\n'
#  '                }\n'
#  '              },\n'
#  '              "type": "object"\n'
#  '            }\n'
#  '          },\n'
#  '          "title": "Scikit learn-based classifier score with probability",\n'
#  '          "type": "object"\n'
#  '        },\n'
#  '        "statistics": {\n'
#  '          "!f1": {\n'
#  '            "labels": {\n'
#  '              "false": 0.985,\n'
#  '              "true": 0.375\n'
#  '            },\n'
#  '            "macro": 0.68,\n'
#  '            "micro": 0.394\n'
#  '          },\n'
#  '          "!precision": {\n'
#  '            "labels": {\n'
#  '              "false": 0.977,\n'
#  '              "true": 0.593\n'
#  '            },\n'
#  '            "macro": 0.785,\n'
#  '            "micro": 0.605\n'
#  '          },\n'
#  '          "!recall": {\n'
#  '            "labels": {\n'
#  '              "false": 0.994,\n'
#  '              "true": 0.274\n'
#  '            },\n'
#  '            "macro": 0.634,\n'
#  '            "micro": 0.297\n'
#  '          },\n'
#  '          "accuracy": {\n'
#  '            "labels": {\n'
#  '              "false": 0.971,\n'
#  '              "true": 0.971\n'
#  '            },\n'
#  '            "macro": 0.971,\n'
#  '            "micro": 0.971\n'
#  '          },\n'
#  '          "counts": {\n'
#  '            "labels": {\n'
#  '              "false": 263,\n'
#  '              "true": 68528\n'
#  '            },\n'
#  '            "n": 68791,\n'
#  '            "predictions": {\n'
#  '              "false": {\n'
#  '                "false": 72,\n'
#  '                "true": 191\n'
#  '              },\n'
#  '              "true": {\n'
#  '                "false": 423,\n'
#  '                "true": 68105\n'
#  '              }\n'
#  '            }\n'
#  '          },\n'
#  '          "f1": {\n'
#  '            "labels": {\n'
#  '              "false": 0.375,\n'
#  '              "true": 0.985\n'
#  '            },\n'
#  '            "macro": 0.68,\n'
#  '            "micro": 0.966\n'
#  '          },\n'
#  '          "filter_rate": {\n'
#  '            "labels": {\n'
#  '              "false": 0.985,\n'
#  '              "true": 0.015\n'
#  '            },\n'
#  '            "macro": 0.5,\n'
#  '            "micro": 0.046\n'
#  '          },\n'
#  '          "fpr": {\n'
#  '            "labels": {\n'
#  '              "false": 0.006,\n'
#  '              "true": 0.726\n'
#  '            },\n'
#  '            "macro": 0.366,\n'
#  '            "micro": 0.703\n'
#  '          },\n'
#  '          "match_rate": {\n'
#  '            "labels": {\n'
#  '              "false": 0.015,\n'
#  '              "true": 0.985\n'
#  '            },\n'
#  '            "macro": 0.5,\n'
#  '            "micro": 0.954\n'
#  '          },\n'
#  '          "pr_auc": {\n'
#  '            "labels": {\n'
#  '              "false": 0.426,\n'
#  '              "true": 0.996\n'
#  '            },\n'
#  '            "macro": 0.711,\n'
#  '            "micro": 0.977\n'
#  '          },\n'
#  '          "precision": {\n'
#  '            "labels": {\n'
#  '              "false": 0.593,\n'
#  '              "true": 0.977\n'
#  '            },\n'
#  '            "macro": 0.785,\n'
#  '            "micro": 0.964\n'
#  '          },\n'
#  '          "rates": {\n'
#  '            "population": {\n'
#  '              "false": 0.032,\n'
#  '              "true": 0.968\n'
#  '            },\n'
#  '            "sample": {\n'
#  '              "false": 0.004,\n'
#  '              "true": 0.996\n'
#  '            }\n'
#  '          },\n'
#  '          "recall": {\n'
#  '            "labels": {\n'
#  '              "false": 0.274,\n'
#  '              "true": 0.994\n'
#  '            },\n'
#  '            "macro": 0.634,\n'
#  '            "micro": 0.971\n'
#  '          },\n'
#  '          "roc_auc": {\n'
#  '            "labels": {\n'
#  '              "false": 0.898,\n'
#  '              "true": 0.899\n'
#  '            },\n'
#  '            "macro": 0.898,\n'
#  '            "micro": 0.899\n'
#  '          }\n'
#  '        },\n'
#  '        "type": "GradientBoosting",\n'
#  '        "version": "0.5.0"\n'
#  '      }\n'
#  '    }\n'
#  '  }\n'
#  '}')

# %% [markdown]
# ###https://ores.wikimedia.org/v3/scores/enwiki

# %% [markdown]
# This is like the scores API call (showing available models and versions), except that it only shows results for the enwiki project.

# %%
call3 = requests.get('https://ores.wikimedia.org/v3/scores/enwiki')
enwiki = call3.json()
c3 = json.dumps(enwiki, indent = 1)
p3 = json.loads(c3)
pprint.pprint(c3, width= 200)
# Out:
# ('{\n'
#  ' "enwiki": {\n'
#  '  "models": {\n'
#  '   "articlequality": {\n'
#  '    "version": "0.8.2"\n'
#  '   },\n'
#  '   "articletopic": {\n'
#  '    "version": "1.2.0"\n'
#  '   },\n'
#  '   "damaging": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "draftquality": {\n'
#  '    "version": "0.2.1"\n'
#  '   },\n'
#  '   "drafttopic": {\n'
#  '    "version": "1.2.0"\n'
#  '   },\n'
#  '   "goodfaith": {\n'
#  '    "version": "0.5.1"\n'
#  '   },\n'
#  '   "wp10": {\n'
#  '    "version": "0.8.2"\n'
#  '   }\n'
#  '  }\n'
#  ' }\n'
#  '}')

# %%
pd.DataFrame.from_dict(enwiki['enwiki']['models'])
# Out:
#         articlequality articletopic damaging  ... drafttopic goodfaith   wp10
# version          0.8.2        1.2.0    0.5.1  ...      1.2.0     0.5.1  0.8.2
#
# [1 rows x 7 columns]

# %% [markdown]
# ###https://ores.wikimedia.org/v3/scores/enwiki?models=draftquality&model_info

# %% [markdown]
# Similar as the model info API part, we now only the infos for our model.

# %%
call4 = requests.get('https://ores.wikimedia.org/v3/scores/enwiki?models=draftquality&model_info')
enwiki_model = call4.json()
c4 = json.dumps(enwiki_model, indent = 1)
p4 = json.loads(c4)
pprint.pprint(c4, width= 200)
# Out:
# ('{\n'
#  ' "enwiki": {\n'
#  '  "models": {\n'
#  '   "draftquality": {\n'
#  '    "environment": {\n'
#  '     "machine": "x86_64",\n'
#  '     "platform": "Linux-4.9.0-11-amd64-x86_64-with-debian-9.12",\n'
#  '     "processor": "",\n'
#  '     "python_branch": "",\n'
#  '     "python_build": [\n'
#  '      "default",\n'
#  '      "Sep 27 2018 17:25:39"\n'
#  '     ],\n'
#  '     "python_compiler": "GCC 6.3.0 20170516",\n'
#  '     "python_implementation": "CPython",\n'
#  '     "python_revision": "",\n'
#  '     "python_version": "3.5.3",\n'
#  '     "release": "4.9.0-11-amd64",\n'
#  '     "revscoring_version": "2.8.2",\n'
#  '     "system": "Linux",\n'
#  '     "version": "#1 SMP Debian 4.9.189-3+deb9u1 (2019-09-20)"\n'
#  '    },\n'
#  '    "params": {\n'
#  '     "ccp_alpha": 0.0,\n'
#  '     "center": false,\n'
#  '     "criterion": "friedman_mse",\n'
#  '     "init": null,\n'
#  '     "label_weights": null,\n'
#  '     "labels": [\n'
#  '      "OK",\n'
#  '      "spam",\n'
#  '      "vandalism",\n'
#  '      "attack"\n'
#  '     ],\n'
#  '     "learning_rate": 0.1,\n'
#  '     "loss": "deviance",\n'
#  '     "max_depth": 5,\n'
#  '     "max_features": "log2",\n'
#  '     "max_leaf_nodes": null,\n'
#  '     "min_impurity_decrease": 0.0,\n'
#  '     "min_impurity_split": null,\n'
#  '     "min_samples_leaf": 1,\n'
#  '     "min_samples_split": 2,\n'
#  '     "min_weight_fraction_leaf": 0.0,\n'
#  '     "multilabel": false,\n'
#  '     "n_estimators": 300,\n'
#  '     "n_iter_no_change": null,\n'
#  '     "population_rates": null,\n'
#  '     "presort": "deprecated",\n'
#  '     "random_state": null,\n'
#  '     "scale": false,\n'
#  '     "subsample": 1.0,\n'
#  '     "tol": 0.0001,\n'
#  '     "validation_fraction": 0.1,\n'
#  '     "verbose": 0,\n'
#  '     "warm_start": false\n'
#  '    },\n'
#  '    "score_schema": {\n'
#  '     "properties": {\n'
#  '      "prediction": {\n'
#  '       "description": "The most likely label predicted by the estimator",\n'
#  '       "type": "string"\n'
#  '      },\n'
#  '      "probability": {\n'
#  '       "description": "A mapping of probabilities onto each of the potential output labels",\n'
#  '       "properties": {\n'
#  '        "OK": {\n'
#  '         "type": "number"\n'
#  '        },\n'
#  '        "attack": {\n'
#  '         "type": "number"\n'
#  '        },\n'
#  '        "spam": {\n'
#  '         "type": "number"\n'
#  '        },\n'
#  '        "vandalism": {\n'
#  '         "type": "number"\n'
#  '        }\n'
#  '       },\n'
#  '       "type": "object"\n'
#  '      }\n'
#  '     },\n'
#  '     "title": "Scikit learn-based classifier score with probability",\n'
#  '     "type": "object"\n'
#  '    },\n'
#  '    "statistics": {\n'
#  '     "!f1": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.656,\n'
#  '       "attack": 0.998,\n'
#  '       "spam": 0.986,\n'
#  '       "vandalism": 0.991\n'
#  '      },\n'
#  '      "macro": 0.908,\n'
#  '      "micro": 0.665\n'
#  '     },\n'
#  '     "!precision": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.544,\n'
#  '       "attack": 0.998,\n'
#  '       "spam": 0.996,\n'
#  '       "vandalism": 0.996\n'
#  '      },\n'
#  '      "macro": 0.884,\n'
#  '      "micro": 0.557\n'
#  '     },\n'
#  '     "!recall": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.824,\n'
#  '       "attack": 0.997,\n'
#  '       "spam": 0.976,\n'
#  '       "vandalism": 0.986\n'
#  '      },\n'
#  '      "macro": 0.946,\n'
#  '      "micro": 0.829\n'
#  '     },\n'
#  '     "accuracy": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.975,\n'
#  '       "attack": 0.995,\n'
#  '       "spam": 0.973,\n'
#  '       "vandalism": 0.982\n'
#  '      },\n'
#  '      "macro": 0.981,\n'
#  '      "micro": 0.975\n'
#  '     },\n'
#  '     "counts": {\n'
#  '      "labels": {\n'
#  '       "OK": 175000,\n'
#  '       "attack": 2059,\n'
#  '       "spam": 17699,\n'
#  '       "vandalism": 6503\n'
#  '      },\n'
#  '      "n": 201261,\n'
#  '      "predictions": {\n'
#  '       "OK": {\n'
#  '        "OK": 171398,\n'
#  '        "attack": 88,\n'
#  '        "spam": 2658,\n'
#  '        "vandalism": 856\n'
#  '       },\n'
#  '       "attack": {\n'
#  '        "OK": 261,\n'
#  '        "attack": 414,\n'
#  '        "spam": 343,\n'
#  '        "vandalism": 1041\n'
#  '       },\n'
#  '       "spam": {\n'
#  '        "OK": 2747,\n'
#  '        "attack": 74,\n'
#  '        "spam": 14038,\n'
#  '        "vandalism": 840\n'
#  '       },\n'
#  '       "vandalism": {\n'
#  '        "OK": 1602,\n'
#  '        "attack": 426,\n'
#  '        "spam": 1366,\n'
#  '        "vandalism": 3109\n'
#  '       }\n'
#  '      }\n'
#  '     },\n'
#  '     "f1": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.987,\n'
#  '       "attack": 0.161,\n'
#  '       "spam": 0.531,\n'
#  '       "vandalism": 0.279\n'
#  '      },\n'
#  '      "macro": 0.489,\n'
#  '      "micro": 0.971\n'
#  '     },\n'
#  '     "filter_rate": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.044,\n'
#  '       "attack": 0.997,\n'
#  '       "spam": 0.961,\n'
#  '       "vandalism": 0.983\n'
#  '      },\n'
#  '      "macro": 0.746,\n'
#  '      "micro": 0.071\n'
#  '     },\n'
#  '     "fpr": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.176,\n'
#  '       "attack": 0.003,\n'
#  '       "spam": 0.024,\n'
#  '       "vandalism": 0.014\n'
#  '      },\n'
#  '      "macro": 0.054,\n'
#  '      "micro": 0.171\n'
#  '     },\n'
#  '     "match_rate": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.956,\n'
#  '       "attack": 0.003,\n'
#  '       "spam": 0.039,\n'
#  '       "vandalism": 0.017\n'
#  '      },\n'
#  '      "macro": 0.254,\n'
#  '      "micro": 0.929\n'
#  '     },\n'
#  '     "pr_auc": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.994,\n'
#  '       "attack": 0.091,\n'
#  '       "spam": 0.616,\n'
#  '       "vandalism": 0.209\n'
#  '      },\n'
#  '      "macro": 0.477,\n'
#  '      "micro": 0.979\n'
#  '     },\n'
#  '     "precision": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.995,\n'
#  '       "attack": 0.134,\n'
#  '       "spam": 0.399,\n'
#  '       "vandalism": 0.197\n'
#  '      },\n'
#  '      "macro": 0.431,\n'
#  '      "micro": 0.975\n'
#  '     },\n'
#  '     "rates": {\n'
#  '      "population": {\n'
#  '       "OK": 0.971,\n'
#  '       "attack": 0.002,\n'
#  '       "spam": 0.02,\n'
#  '       "vandalism": 0.007\n'
#  '      },\n'
#  '      "sample": {\n'
#  '       "OK": 0.87,\n'
#  '       "attack": 0.01,\n'
#  '       "spam": 0.088,\n'
#  '       "vandalism": 0.032\n'
#  '      }\n'
#  '     },\n'
#  '     "recall": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.979,\n'
#  '       "attack": 0.201,\n'
#  '       "spam": 0.793,\n'
#  '       "vandalism": 0.478\n'
#  '      },\n'
#  '      "macro": 0.613,\n'
#  '      "micro": 0.97\n'
#  '     },\n'
#  '     "roc_auc": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.979,\n'
#  '       "attack": 0.968,\n'
#  '       "spam": 0.979,\n'
#  '       "vandalism": 0.955\n'
#  '      },\n'
#  '      "macro": 0.97,\n'
#  '      "micro": 0.979\n'
#  '     }\n'
#  '    },\n'
#  '    "type": "GradientBoosting",\n'
#  '    "version": "0.2.1"\n'
#  '   }\n'
#  '  }\n'
#  ' }\n'
#  '}')

# %% [markdown]
# ### https://ores.wikimedia.org/v3/scores/enwiki?models=draftquality&revids=641962088

# %% [markdown]
# For this API we used the rev ID from the github wikimedia page which was listed as an example. Using this ID it can be seen, that this was predicted as spam with our used model.

# %%
call5 = requests.get('https://ores.wikimedia.org/v3/scores/enwiki?models=draftquality&revids=641962088')
rev = call5.json()
c5 = json.dumps(rev, indent = 1)
p5 = json.loads(c5)
pprint.pprint(c5, width= 200)
# Out:
# ('{\n'
#  ' "enwiki": {\n'
#  '  "models": {\n'
#  '   "draftquality": {\n'
#  '    "version": "0.2.1"\n'
#  '   }\n'
#  '  },\n'
#  '  "scores": {\n'
#  '   "641962088": {\n'
#  '    "draftquality": {\n'
#  '     "score": {\n'
#  '      "prediction": "spam",\n'
#  '      "probability": {\n'
#  '       "OK": 0.11366053720369897,\n'
#  '       "attack": 0.01792559000882414,\n'
#  '       "spam": 0.793175595649904,\n'
#  '       "vandalism": 0.07523827713757288\n'
#  '      }\n'
#  '     }\n'
#  '    }\n'
#  '   }\n'
#  '  }\n'
#  ' }\n'
#  '}')

# %% [markdown]
# ###https://ores.wikimedia.org/v3/scores/enwiki/641962088/draftquality?model_info

# %% [markdown]
# This API call gives us the opportunity to use a certain rev ID and receive model information, like the model info API call.

# %%
call6 = requests.get('https://ores.wikimedia.org/v3/scores/enwiki/641962088/draftquality?model_info')
rev = call6.json()
c6 = json.dumps(rev, indent = 1)
p6 = json.loads(c6)
pprint.pprint(c6, width= 200)
# Out:
# ('{\n'
#  ' "enwiki": {\n'
#  '  "models": {\n'
#  '   "draftquality": {\n'
#  '    "environment": {\n'
#  '     "machine": "x86_64",\n'
#  '     "platform": "Linux-4.9.0-11-amd64-x86_64-with-debian-9.12",\n'
#  '     "processor": "",\n'
#  '     "python_branch": "",\n'
#  '     "python_build": [\n'
#  '      "default",\n'
#  '      "Sep 27 2018 17:25:39"\n'
#  '     ],\n'
#  '     "python_compiler": "GCC 6.3.0 20170516",\n'
#  '     "python_implementation": "CPython",\n'
#  '     "python_revision": "",\n'
#  '     "python_version": "3.5.3",\n'
#  '     "release": "4.9.0-11-amd64",\n'
#  '     "revscoring_version": "2.8.2",\n'
#  '     "system": "Linux",\n'
#  '     "version": "#1 SMP Debian 4.9.189-3+deb9u1 (2019-09-20)"\n'
#  '    },\n'
#  '    "params": {\n'
#  '     "ccp_alpha": 0.0,\n'
#  '     "center": false,\n'
#  '     "criterion": "friedman_mse",\n'
#  '     "init": null,\n'
#  '     "label_weights": null,\n'
#  '     "labels": [\n'
#  '      "OK",\n'
#  '      "spam",\n'
#  '      "vandalism",\n'
#  '      "attack"\n'
#  '     ],\n'
#  '     "learning_rate": 0.1,\n'
#  '     "loss": "deviance",\n'
#  '     "max_depth": 5,\n'
#  '     "max_features": "log2",\n'
#  '     "max_leaf_nodes": null,\n'
#  '     "min_impurity_decrease": 0.0,\n'
#  '     "min_impurity_split": null,\n'
#  '     "min_samples_leaf": 1,\n'
#  '     "min_samples_split": 2,\n'
#  '     "min_weight_fraction_leaf": 0.0,\n'
#  '     "multilabel": false,\n'
#  '     "n_estimators": 300,\n'
#  '     "n_iter_no_change": null,\n'
#  '     "population_rates": null,\n'
#  '     "presort": "deprecated",\n'
#  '     "random_state": null,\n'
#  '     "scale": false,\n'
#  '     "subsample": 1.0,\n'
#  '     "tol": 0.0001,\n'
#  '     "validation_fraction": 0.1,\n'
#  '     "verbose": 0,\n'
#  '     "warm_start": false\n'
#  '    },\n'
#  '    "score_schema": {\n'
#  '     "properties": {\n'
#  '      "prediction": {\n'
#  '       "description": "The most likely label predicted by the estimator",\n'
#  '       "type": "string"\n'
#  '      },\n'
#  '      "probability": {\n'
#  '       "description": "A mapping of probabilities onto each of the potential output labels",\n'
#  '       "properties": {\n'
#  '        "OK": {\n'
#  '         "type": "number"\n'
#  '        },\n'
#  '        "attack": {\n'
#  '         "type": "number"\n'
#  '        },\n'
#  '        "spam": {\n'
#  '         "type": "number"\n'
#  '        },\n'
#  '        "vandalism": {\n'
#  '         "type": "number"\n'
#  '        }\n'
#  '       },\n'
#  '       "type": "object"\n'
#  '      }\n'
#  '     },\n'
#  '     "title": "Scikit learn-based classifier score with probability",\n'
#  '     "type": "object"\n'
#  '    },\n'
#  '    "statistics": {\n'
#  '     "!f1": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.656,\n'
#  '       "attack": 0.998,\n'
#  '       "spam": 0.986,\n'
#  '       "vandalism": 0.991\n'
#  '      },\n'
#  '      "macro": 0.908,\n'
#  '      "micro": 0.665\n'
#  '     },\n'
#  '     "!precision": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.544,\n'
#  '       "attack": 0.998,\n'
#  '       "spam": 0.996,\n'
#  '       "vandalism": 0.996\n'
#  '      },\n'
#  '      "macro": 0.884,\n'
#  '      "micro": 0.557\n'
#  '     },\n'
#  '     "!recall": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.824,\n'
#  '       "attack": 0.997,\n'
#  '       "spam": 0.976,\n'
#  '       "vandalism": 0.986\n'
#  '      },\n'
#  '      "macro": 0.946,\n'
#  '      "micro": 0.829\n'
#  '     },\n'
#  '     "accuracy": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.975,\n'
#  '       "attack": 0.995,\n'
#  '       "spam": 0.973,\n'
#  '       "vandalism": 0.982\n'
#  '      },\n'
#  '      "macro": 0.981,\n'
#  '      "micro": 0.975\n'
#  '     },\n'
#  '     "counts": {\n'
#  '      "labels": {\n'
#  '       "OK": 175000,\n'
#  '       "attack": 2059,\n'
#  '       "spam": 17699,\n'
#  '       "vandalism": 6503\n'
#  '      },\n'
#  '      "n": 201261,\n'
#  '      "predictions": {\n'
#  '       "OK": {\n'
#  '        "OK": 171398,\n'
#  '        "attack": 88,\n'
#  '        "spam": 2658,\n'
#  '        "vandalism": 856\n'
#  '       },\n'
#  '       "attack": {\n'
#  '        "OK": 261,\n'
#  '        "attack": 414,\n'
#  '        "spam": 343,\n'
#  '        "vandalism": 1041\n'
#  '       },\n'
#  '       "spam": {\n'
#  '        "OK": 2747,\n'
#  '        "attack": 74,\n'
#  '        "spam": 14038,\n'
#  '        "vandalism": 840\n'
#  '       },\n'
#  '       "vandalism": {\n'
#  '        "OK": 1602,\n'
#  '        "attack": 426,\n'
#  '        "spam": 1366,\n'
#  '        "vandalism": 3109\n'
#  '       }\n'
#  '      }\n'
#  '     },\n'
#  '     "f1": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.987,\n'
#  '       "attack": 0.161,\n'
#  '       "spam": 0.531,\n'
#  '       "vandalism": 0.279\n'
#  '      },\n'
#  '      "macro": 0.489,\n'
#  '      "micro": 0.971\n'
#  '     },\n'
#  '     "filter_rate": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.044,\n'
#  '       "attack": 0.997,\n'
#  '       "spam": 0.961,\n'
#  '       "vandalism": 0.983\n'
#  '      },\n'
#  '      "macro": 0.746,\n'
#  '      "micro": 0.071\n'
#  '     },\n'
#  '     "fpr": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.176,\n'
#  '       "attack": 0.003,\n'
#  '       "spam": 0.024,\n'
#  '       "vandalism": 0.014\n'
#  '      },\n'
#  '      "macro": 0.054,\n'
#  '      "micro": 0.171\n'
#  '     },\n'
#  '     "match_rate": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.956,\n'
#  '       "attack": 0.003,\n'
#  '       "spam": 0.039,\n'
#  '       "vandalism": 0.017\n'
#  '      },\n'
#  '      "macro": 0.254,\n'
#  '      "micro": 0.929\n'
#  '     },\n'
#  '     "pr_auc": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.994,\n'
#  '       "attack": 0.091,\n'
#  '       "spam": 0.616,\n'
#  '       "vandalism": 0.209\n'
#  '      },\n'
#  '      "macro": 0.477,\n'
#  '      "micro": 0.979\n'
#  '     },\n'
#  '     "precision": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.995,\n'
#  '       "attack": 0.134,\n'
#  '       "spam": 0.399,\n'
#  '       "vandalism": 0.197\n'
#  '      },\n'
#  '      "macro": 0.431,\n'
#  '      "micro": 0.975\n'
#  '     },\n'
#  '     "rates": {\n'
#  '      "population": {\n'
#  '       "OK": 0.971,\n'
#  '       "attack": 0.002,\n'
#  '       "spam": 0.02,\n'
#  '       "vandalism": 0.007\n'
#  '      },\n'
#  '      "sample": {\n'
#  '       "OK": 0.87,\n'
#  '       "attack": 0.01,\n'
#  '       "spam": 0.088,\n'
#  '       "vandalism": 0.032\n'
#  '      }\n'
#  '     },\n'
#  '     "recall": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.979,\n'
#  '       "attack": 0.201,\n'
#  '       "spam": 0.793,\n'
#  '       "vandalism": 0.478\n'
#  '      },\n'
#  '      "macro": 0.613,\n'
#  '      "micro": 0.97\n'
#  '     },\n'
#  '     "roc_auc": {\n'
#  '      "labels": {\n'
#  '       "OK": 0.979,\n'
#  '       "attack": 0.968,\n'
#  '       "spam": 0.979,\n'
#  '       "vandalism": 0.955\n'
#  '      },\n'
#  '      "macro": 0.97,\n'
#  '      "micro": 0.979\n'
#  '     }\n'
#  '    },\n'
#  '    "type": "GradientBoosting",\n'
#  '    "version": "0.2.1"\n'
#  '   }\n'
#  '  },\n'
#  '  "scores": {\n'
#  '   "641962088": {\n'
#  '    "draftquality": {\n'
#  '     "score": {\n'
#  '      "prediction": "spam",\n'
#  '      "probability": {\n'
#  '       "OK": 0.11366053720369897,\n'
#  '       "attack": 0.01792559000882414,\n'
#  '       "spam": 0.793175595649904,\n'
#  '       "vandalism": 0.07523827713757288\n'
#  '      }\n'
#  '     }\n'
#  '    }\n'
#  '   }\n'
#  '  }\n'
#  ' }\n'
#  '}')

# %% [markdown]
# ###https://ores.wikimedia.org/v3/scores/enwiki/641962088/draftquality?features=true

# %% [markdown]
# This gives an overview of the used features for this model ad the associated rev ID.

# %%
call7 = requests.get('https://ores.wikimedia.org/v3/scores/enwiki/641962088/draftquality?features=true')
rev = call7.json()
c7 = json.dumps(rev, indent = 1)
p7 = json.loads(c7)
pprint.pprint(c7, width= 200)
# Out:
# ('{\n'
#  ' "enwiki": {\n'
#  '  "models": {\n'
#  '   "draftquality": {\n'
#  '    "version": "0.2.1"\n'
#  '   }\n'
#  '  },\n'
#  '  "scores": {\n'
#  '   "641962088": {\n'
#  '    "draftquality": {\n'
#  '     "features": {\n'
#  '      "feature.english.sentiment.revision.negative_polarity": 0.125,\n'
#  '      "feature.english.sentiment.revision.positive_polarity": 1.0,\n'
#  '      "feature.english.stemmed.revision.stems_length": 93,\n'
#  '      "feature.enwiki.main_article_templates": 0.0,\n'
#  '      "feature.enwiki.revision.category_links": 0.0,\n'
#  '      "feature.enwiki.revision.cite_templates": 0.0,\n'
#  '      "feature.enwiki.revision.cn_templates": 0.0,\n'
#  '      "feature.enwiki.revision.image_links": 0.0,\n'
#  '      "feature.enwiki.revision.infobox_templates": 0.0,\n'
#  '      "feature.len(<datasource.english.badwords.revision.matches>)": 0.0,\n'
#  '      "feature.len(<datasource.english.dictionary.revision.dict_words>)": 21.0,\n'
#  '      "feature.len(<datasource.english.dictionary.revision.non_dict_words>)": 0.0,\n'
#  '      "feature.len(<datasource.english.informals.revision.matches>)": 0.0,\n'
#  '      "feature.len(<datasource.english.words_to_watch.revision.matches>)": 1.0,\n'
#  '      "feature.len(<datasource.tokenized(datasource.revision.text)>)": 51.0,\n'
#  '      "feature.len(<datasource.wikitext.revision.breaks>)": 4.0,\n'
#  '      "feature.len(<datasource.wikitext.revision.cjks>)": 0.0,\n'
#  '      "feature.len(<datasource.wikitext.revision.entities>)": 0.0,\n'
#  '      "feature.len(<datasource.wikitext.revision.markups>)": 0.0,\n'
#  '      "feature.len(<datasource.wikitext.revision.numbers>)": 0.0,\n'
#  '      "feature.len(<datasource.wikitext.revision.punctuations>)": 2.0,\n'
#  '      "feature.len(<datasource.wikitext.revision.uppercase_words>)": 0.0,\n'
#  '      "feature.len(<datasource.wikitext.revision.urls>)": 4.0,\n'
#  '      "feature.len(<datasource.wikitext.revision.whitespaces>)": 20.0,\n'
#  '      "feature.len(<datasource.wikitext.revision.words>)": 21.0,\n'
#  '      "feature.max(<datasource.map(<built-in function len>, <datasource.tokenized(datasource.revision.text)>)>)": 122,\n'
#  '      "feature.max(<datasource.map(<built-in function len>, <datasource.wikitext.revision.words>)>)": 12,\n'
#  '      "feature.wikitext.revision.break_chars": 8,\n'
#  '      "feature.wikitext.revision.chars": 589.0,\n'
#  '      "feature.wikitext.revision.cjk_chars": 0,\n'
#  '      "feature.wikitext.revision.content_chars": 589.0,\n'
#  '      "feature.wikitext.revision.entity_chars": 0,\n'
#  '      "feature.wikitext.revision.external_links": 4.0,\n'
#  '      "feature.wikitext.revision.headings": 0.0,\n'
#  '      "feature.wikitext.revision.longest_repeated_char": 3,\n'
#  '      "feature.wikitext.revision.markup_chars": 0,\n'
#  '      "feature.wikitext.revision.punctuation_chars": 2,\n'
#  '      "feature.wikitext.revision.ref_tags": 0.0,\n'
#  '      "feature.wikitext.revision.tags": 0.0,\n'
#  '      "feature.wikitext.revision.templates": 0.0,\n'
#  '      "feature.wikitext.revision.uppercase_word_chars": 0,\n'
#  '      "feature.wikitext.revision.url_chars": 455,\n'
#  '      "feature.wikitext.revision.whitespace_chars": 20,\n'
#  '      "feature.wikitext.revision.wikilinks": 0.0,\n'
#  '      "feature.wikitext.revision.word_chars": 104\n'
#  '     },\n'
#  '     "score": {\n'
#  '      "prediction": "spam",\n'
#  '      "probability": {\n'
#  '       "OK": 0.11366053720369897,\n'
#  '       "attack": 0.01792559000882414,\n'
#  '       "spam": 0.793175595649904,\n'
#  '       "vandalism": 0.07523827713757288\n'
#  '      }\n'
#  '     }\n'
#  '    }\n'
#  '   }\n'
#  '  }\n'
#  ' }\n'
#  '}')

# %% [markdown]
# ### Feature Injection

# %% [markdown]
# To inject a feature we first have to check which features were used.

# %%
feat_inj = requests.get('https://ores.wikimedia.org/v3/scores/enwiki/21312312/articlequality?features')
fi = feat_inj.json()
c8 = json.dumps(fi, indent = 1)
p8 = json.loads(c8)
pprint.pprint(p8, width= 200)
# Out:
# {'enwiki': {'models': {'articlequality': {'version': '0.8.2'}},
#             'scores': {'21312312': {'articlequality': {'features': {'feature.english.stemmed.revision.stems_length': 3926,
#                                                                     'feature.enwiki.infobox_images': 0,
#                                                                     'feature.enwiki.main_article_templates': 0.0,
#                                                                     'feature.enwiki.revision.category_links': 3.0,
#                                                                     'feature.enwiki.revision.cite_templates': 0.0,
#                                                                     'feature.enwiki.revision.cn_templates': 0.0,
#                                                                     'feature.enwiki.revision.image_links': 0.0,
#                                                                     'feature.enwiki.revision.image_template': 0.0,
#                                                                     'feature.enwiki.revision.images_in_tags': 0,
#                                                                     'feature.enwiki.revision.images_in_templates': 0,
#                                                                     'feature.enwiki.revision.infobox_templates': 0.0,
#                                                                     'feature.enwiki.revision.paragraphs_without_refs_total_length': 5863.0,
#                                                                     'feature.enwiki.revision.shortened_footnote_templates': 0.0,
#                                                                     'feature.enwiki.revision.who_templates': 0.0,
#                                                                     'feature.len(<datasource.english.idioms.revision.matches>)': 0.0,
#                                                                     'feature.len(<datasource.english.words_to_watch.revision.matches>)': 15.0,
#                                                                     'feature.len(<datasource.wikitext.revision.words>)': 861.0,
#                                                                     'feature.wikitext.revision.chars': 5894.0,
#                                                                     'feature.wikitext.revision.content_chars': 5208.0,
#                                                                     'feature.wikitext.revision.external_links': 0.0,
#                                                                     'feature.wikitext.revision.headings_by_level(2)': 3.0,
#                                                                     'feature.wikitext.revision.headings_by_level(3)': 2.0,
#                                                                     'feature.wikitext.revision.ref_tags': 0.0,
#                                                                     'feature.wikitext.revision.templates': 5.0,
#                                                                     'feature.wikitext.revision.wikilinks': 73.0},
#                                                        'score': {'prediction': 'Start',
#                                                                  'probability': {'B': 0.23776933204655176,
#                                                                                  'C': 0.13358945258161725,
#                                                                                  'FA': 0.006881530486026957,
#                                                                                  'GA': 0.009387151285779235,
#                                                                                  'Start': 0.5878400472447988,
#                                                                                  'Stub': 0.024532486355225997}}}}}}}

# %% [markdown]
# By using the example from https://www.mediawiki.org/wiki/ORES/Feature_injection the prediction should change, but it does not. So we can't figure out which influence the feature injection has.

# %%
feat_inj = requests.get('https://ores.wikimedia.org/v3/scores/enwiki/21312312/articlequality?features/feature.enwiki.revision.cite_templates=13.0/feature.enwiki.revision.paragraphs_without_refs_total_length=0.0/feature.wikitext.revision.ref_tags=13.0/feature.wikitext.revision.templates=18.0')
fi = feat_inj.json()
c8 = json.dumps(fi, indent = 1)
p8 = json.loads(c8)
pprint.pprint(p8, width= 200)
# Out:
# {'enwiki': {'models': {'articlequality': {'version': '0.8.2'}},
#             'scores': {'21312312': {'articlequality': {'score': {'prediction': 'Start',
#                                                                  'probability': {'B': 0.23776933204655176,
#                                                                                  'C': 0.13358945258161725,
#                                                                                  'FA': 0.006881530486026957,
#                                                                                  'GA': 0.009387151285779235,
#                                                                                  'Start': 0.5878400472447988,
#                                                                                  'Stub': 0.024532486355225997}}}}}}}

# %% [markdown]
# ## [3] ML algorithm and training/test data
# > Which machine learning model is underlying and what data is used to build the model?

# %% [markdown]
# * Check out `model_info` in detail.
# * What does it tell you about the model performance?
#
#   * It gives information about different metrics, such as precision, accuracy, or match rate, which shows that the accuracy for example is actually very high, considering that for all categories (OK, spam, attack, ...) it is well over 95 %.
#
# * You can visualise and explain your results regarding model performance.
# * What data was used to train and test the model?
#
#   * Already reviewed articles with the labels ["OK", "spam", "vandalism", "attack"] were used to train the model
#
# * What machine learning algorithm is your model using? Please explain briefly.
#
#   * Gradient Boost: using multiple weaker models, that makeup a stronger model overall by having the models learn from each others mistakes

# %%
call = requests.get('https://ores.wikimedia.org/v3/scores/enwiki?models=draftquality&model_info')
model_info = call.json()

# %%
params_dict = {'params': [],'value':[]}
params_df = pd.DataFrame(params_dict, columns = ['params','value' ])

for key in model_info['enwiki']['models']['draftquality']['params'].keys():
  values = model_info['enwiki']['models']['draftquality']['params'][key]

  params_df = params_df.append({'params':key,'value': values}, ignore_index=True)

# %%
params_df
# Out:
#                       params                          value
# 0                  ccp_alpha                              0
# 1                     center                              0
# 2                  criterion                   friedman_mse
# 3                       init                           None
# 4              label_weights                           None
# 5                     labels  [OK, spam, vandalism, attack]
# 6              learning_rate                            0.1
# 7                       loss                       deviance
# 8                  max_depth                              5
# 9               max_features                           log2
# 10            max_leaf_nodes                           None
# 11     min_impurity_decrease                              0
# 12        min_impurity_split                           None
# 13          min_samples_leaf                              1
# 14         min_samples_split                              2
# 15  min_weight_fraction_leaf                              0
# 16                multilabel                          False
# 17              n_estimators                            300
# 18          n_iter_no_change                           None
# 19          population_rates                           None
# 20                   presort                     deprecated
# 21              random_state                           None
# 22                     scale                          False
# 23                 subsample                              1
# 24                       tol                         0.0001
# 25       validation_fraction                            0.1
# 26                   verbose                              0
# 27                warm_start                          False

# %%
metrics_dict = {'metrics': [],'value':[]}
metrics_df = pd.DataFrame(metrics_dict, columns = ['metrics','value' ])

for key in model_info['enwiki']['models']['draftquality']['statistics'].keys():
 for key2 in model_info['enwiki']['models']['draftquality']['statistics'][key].keys():
    value = model_info['enwiki']['models']['draftquality']['statistics'][key][key2]

    metrics_df = metrics_df.append({'metrics':key+' ('+key2+')','value': value}, ignore_index=True)

# %%
metrics_df
# Out:
#                  metrics                                              value
# 0           !f1 (labels)  {'OK': 0.656, 'attack': 0.998, 'spam': 0.986, ...
# 1            !f1 (macro)                                              0.908
# 2            !f1 (micro)                                              0.665
# 3    !precision (labels)  {'OK': 0.544, 'attack': 0.998, 'spam': 0.996, ...
# 4     !precision (macro)                                              0.884
# 5     !precision (micro)                                              0.557
# 6       !recall (labels)  {'OK': 0.824, 'attack': 0.997, 'spam': 0.976, ...
# 7        !recall (macro)                                              0.946
# 8        !recall (micro)                                              0.829
# 9      accuracy (labels)  {'OK': 0.975, 'attack': 0.995, 'spam': 0.973, ...
# 10      accuracy (macro)                                              0.981
# 11      accuracy (micro)                                              0.975
# 12       counts (labels)  {'OK': 175000, 'attack': 2059, 'spam': 17699, ...
# 13            counts (n)                                             201261
# 14  counts (predictions)  {'OK': {'OK': 171398, 'attack': 88, 'spam': 26...
# 15           f1 (labels)  {'OK': 0.987, 'attack': 0.161, 'spam': 0.531, ...
# 16            f1 (macro)                                              0.489
# 17            f1 (micro)                                              0.971
# 18  filter_rate (labels)  {'OK': 0.044, 'attack': 0.997, 'spam': 0.961, ...
# 19   filter_rate (macro)                                              0.746
# 20   filter_rate (micro)                                              0.071
# 21          fpr (labels)  {'OK': 0.176, 'attack': 0.003, 'spam': 0.024, ...
# 22           fpr (macro)                                              0.054
# 23           fpr (micro)                                              0.171
# 24   match_rate (labels)  {'OK': 0.956, 'attack': 0.003, 'spam': 0.039, ...
# 25    match_rate (macro)                                              0.254
# 26    match_rate (micro)                                              0.929
# 27       pr_auc (labels)  {'OK': 0.994, 'attack': 0.091, 'spam': 0.616, ...
# 28        pr_auc (macro)                                              0.477
# 29        pr_auc (micro)                                              0.979
# 30    precision (labels)  {'OK': 0.995, 'attack': 0.134, 'spam': 0.399, ...
# 31     precision (macro)                                              0.431
# 32     precision (micro)                                              0.975
# 33    rates (population)  {'OK': 0.971, 'attack': 0.002, 'spam': 0.02, '...
# 34        rates (sample)  {'OK': 0.87, 'attack': 0.01, 'spam': 0.088, 'v...
# 35       recall (labels)  {'OK': 0.979, 'attack': 0.201, 'spam': 0.793, ...
# 36        recall (macro)                                              0.613
# 37        recall (micro)                                               0.97
# 38      roc_auc (labels)  {'OK': 0.979, 'attack': 0.968, 'spam': 0.979, ...
# 39       roc_auc (macro)                                               0.97
# 40       roc_auc (micro)                                              0.979

# %%
print( "The used model is: ", model_info['enwiki']['models']['draftquality']['type'], ', Version: ', model_info['enwiki']['models']['draftquality']['version'] )
# Out:
# The used model is:  GradientBoosting , Version:  0.2.1

# %% [markdown]
# ## [4] Features
# > Which features are used and which have the greatest influence on the prediction?
#
# * What features is your model using?
#   * The used features can be seen in the output below.
#
# * What do they mean?
#   * There are several features. The first two are for example if the sentiment of the revision was rather positive or more negative. All features are about the revision of the article. For example revision length. This information are used to detect if the article is "Ok" or spam or vandalism. If there are e.g. no/short revisions for this article or only a few references it is most likely spam or something else.
#
# * Which is the most important feature?
#   * The feature "feature.wikitext.revision.chars" is with a value of 498512 the most important feature.
#
# * The API call `https://ores.wikimedia.org/v3/scores/enwiki/991379667/draftquality?features=true` is used in this example.
#
# * Are all models (in all languages of wikipedia), are they using the same features?
#   * No, since ORES is only available in 14 different languages.
#   * In addition not all projects support the model "draftquality"

# %%
calli = requests.get('https://ores.wikimedia.org/v3/scores/enwiki/991379667/draftquality?features=true')
features = calli.json()

# %%
feature_dict = {'feature': [],'value':[]}
feature_df = pd.DataFrame(feature_dict, columns = ['feature','value' ])

for feature in features['enwiki']['scores']['991379667']['draftquality']['features'].keys():
  value = features['enwiki']['scores']['991379667']['draftquality']['features'][feature]
  feature_df = feature_df.append({ 'feature': feature, 'value':value }, ignore_index=True)

# %%
feature_df
# Out:
#                                               feature       value
# 0   feature.english.sentiment.revision.negative_po...     689.403
# 1   feature.english.sentiment.revision.positive_po...    1085.597
# 2       feature.english.stemmed.revision.stems_length  247938.000
# 3               feature.enwiki.main_article_templates      48.000
# 4              feature.enwiki.revision.category_links      42.000
# 5              feature.enwiki.revision.cite_templates     999.000
# 6                feature.enwiki.revision.cn_templates       0.000
# 7                 feature.enwiki.revision.image_links      40.000
# 8           feature.enwiki.revision.infobox_templates       1.000
# 9   feature.len(<datasource.english.badwords.revis...      57.000
# 10  feature.len(<datasource.english.dictionary.rev...   47301.000
# 11  feature.len(<datasource.english.dictionary.rev...    5340.000
# 12  feature.len(<datasource.english.informals.revi...     103.000
# 13  feature.len(<datasource.english.words_to_watch...     459.000
# 14  feature.len(<datasource.tokenized(datasource.r...  139774.000
# 15  feature.len(<datasource.wikitext.revision.brea...     400.000
# 16   feature.len(<datasource.wikitext.revision.cjks>)       0.000
# 17  feature.len(<datasource.wikitext.revision.enti...      83.000
# 18  feature.len(<datasource.wikitext.revision.mark...   14437.000
# 19  feature.len(<datasource.wikitext.revision.numb...    5004.000
# 20  feature.len(<datasource.wikitext.revision.punc...    5458.000
# 21  feature.len(<datasource.wikitext.revision.uppe...     705.000
# 22   feature.len(<datasource.wikitext.revision.urls>)    1015.000
# 23  feature.len(<datasource.wikitext.revision.whit...   47654.000
# 24  feature.len(<datasource.wikitext.revision.words>)   52641.000
# 25  feature.max(<datasource.map(<built-in function...     241.000
# 26  feature.max(<datasource.map(<built-in function...      20.000
# 27              feature.wikitext.revision.break_chars     800.000
# 28                    feature.wikitext.revision.chars  498512.000
# 29                feature.wikitext.revision.cjk_chars       0.000
# 30            feature.wikitext.revision.content_chars  132826.000
# 31             feature.wikitext.revision.entity_chars     504.000
# 32           feature.wikitext.revision.external_links    1014.000
# 33                 feature.wikitext.revision.headings     107.000
# 34    feature.wikitext.revision.longest_repeated_char      17.000
# 35             feature.wikitext.revision.markup_chars   21329.000
# 36        feature.wikitext.revision.punctuation_chars    5480.000
# 37                 feature.wikitext.revision.ref_tags    1103.000
# 38                     feature.wikitext.revision.tags    1229.000
# 39                feature.wikitext.revision.templates    1194.000
# 40     feature.wikitext.revision.uppercase_word_chars    2312.000
# 41                feature.wikitext.revision.url_chars   97827.000
# 42         feature.wikitext.revision.whitespace_chars   47947.000
# 43                feature.wikitext.revision.wikilinks    1966.000
# 44               feature.wikitext.revision.word_chars  278512.000

# %% [markdown]
# For other wiki projects, the features for this model are not available.

# %% [markdown]
# ***
#
# #### Credits
#
# We release the notebooks under the [Creative Commons Attribution license (CC BY 4.0)](https://creativecommons.org/licenses/by/4.0/).
